# %%
import sys
print(sys.path)
# Out:
# ['/Users/alan/GitHub/Home/glass/src', '/opt/homebrew/Caskroom/miniforge/base/envs/air-power/lib/python313.zip', '/opt/homebrew/Caskroom/miniforge/base/envs/air-power/lib/python3.13', '/opt/homebrew/Caskroom/miniforge/base/envs/air-power/lib/python3.13/lib-dynload', '', '/opt/homebrew/Caskroom/miniforge/base/envs/air-power/lib/python3.13/site-packages']

# %%
from glass import *

# %%
def prettyname(name, counter):
    if counter:
        name = name.replace(" ", "\n  ")
        #name = name.replace("\n  squad", "")
        #name = name.replace("\n  section", " ")
        #name = name.replace("\n  platoon", "  ")
        #name = name.replace("\n  battery", "   ")
    else:
        name = name.replace(" squad", "")
        name = name.replace(" section", " ")
        name = name.replace(" platoon", "  ")
        name = name.replace(" battery", "   ")        
    return name

# %%
for counter in [False, True]:

    startgamesetup(
        None,
        sheets=[["P"]],
        style="temperate",
        writelogfiles=False,
        dotsperhex=80,
    )

    x = 3
    y = 3

    for s in [

        "infantry platoon",
        "infantry weapons platoon",
        "infantry mortar platoon",
        "infantry FAC squad",
        "infantry SAM squad",
        "infantry heavy SAM squad",
        "",
        "",
        "",
        "",
        "",

        "heavy tank platoon",
        "medium tank platoon",
        "light tank platoon",
        "open tank platoon",
        "medium anti-tank platoon",
        "light anti-tank platoon",
        "towed anti-tank battery",
        "light reconnaissance platoon",
        "open reconnaissance platoon",
        "",
        "",


        "medium IFV platoon",
        "light IFV platoon",
        "heavy APC platoon",
        "medium APC platoon",
        "light APC platoon",
        "open APC platoon",
        "infantry HQ platoon",
        "mobile HQ platoon",
        "armored HQ platoon",
        "",
        "",


        "armored mortar platoon",
        "towed mortar platoon",
        "light armored artillery battery",
        "open armored artillery battery",
        "tracked artillery battery",
        "mobile artillery battery",
        "towed artillery battery",
        "armored rocket artillery battery",
        "mobile rocket artillery battery",
        "tracked missile artillery battery",
        "mobile missile artillery battery",

        "truck platoon",
        "light truck platoon",
        "tracked carrier platoon",
    ]:
        if s != "":
            if s.startswith("KS"):
                azimuth = "ENE"
            else:
                azimuth = None
            hexcode = "P-%02d%02d" % (x + 0, y)
            name = prettyname(s, counter)
            setupgroundunit(name, hexcode, s, azimuth=azimuth, color="lightgreen", counter=counter, identified=True)
        if y == 13:
            x += 2
            y = 3
        else:
            y += 1

    drawmap(zoom=False,xmin=1.5,xmax=13.5,ymin=11.5,ymax=23.5)

# !mv map-00.png figure-ground-combat-units.png
# Out:
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['P']].
# set-up      : north is up.
# set-up      : map option style is 'temperate'.
# set-up      : map option dotsperhex is 80.
#
# set-up      :       :       : creating ground unit infantry  .
# set-up      :       :       : type is infantry platoon.
#
# set-up      :       :       : creating ground unit infantry weapons  .
# set-up      :       :       : type is infantry weapons platoon.
#
# set-up      :       :       : creating ground unit infantry mortar  .
# set-up      :       :       : type is infantry mortar platoon.
#
# set-up      :       :       : creating ground unit infantry FAC.
# set-up      :       :       : type is infantry FAC squad.
#
# set-up      :       :       : creating ground unit infantry SAM.
# set-up      :       :       : type is infantry SAM squad.
#
# set-up      :       :       : creating ground unit infantry heavy SAM.
# set-up      :       :       : type is infantry heavy SAM squad.
#
# set-up      :       :       : creating ground unit heavy tank  .
# set-up      :       :       : type is heavy tank platoon.
#
# set-up      :       :       : creating ground unit medium tank  .
# set-up      :       :       : type is medium tank platoon.
#
# set-up      :       :       : creating ground unit light tank  .
# set-up      :       :       : type is light tank platoon.
#
# set-up      :       :       : creating ground unit open tank  .
# set-up      :       :       : type is open tank platoon.
#
# set-up      :       :       : creating ground unit medium anti-tank  .
# set-up      :       :       : type is medium anti-tank platoon.
#
# set-up      :       :       : creating ground unit light anti-tank  .
# set-up      :       :       : type is light anti-tank platoon.
#
# set-up      :       :       : creating ground unit towed anti-tank   .
# set-up      :       :       : type is towed anti-tank battery.
#
# set-up      :       :       : creating ground unit light reconnaissance  .
# set-up      :       :       : type is light reconnaissance platoon.
#
# set-up      :       :       : creating ground unit open reconnaissance  .
# set-up      :       :       : type is open reconnaissance platoon.
#
# set-up      :       :       : creating ground unit medium IFV  .
# set-up      :       :       : type is medium IFV platoon.
#
# set-up      :       :       : creating ground unit light IFV  .
# set-up      :       :       : type is light IFV platoon.
#
# set-up      :       :       : creating ground unit heavy APC  .
# set-up      :       :       : type is heavy APC platoon.
#
# set-up      :       :       : creating ground unit medium APC  .
# set-up      :       :       : type is medium APC platoon.
#
# set-up      :       :       : creating ground unit light APC  .
# set-up      :       :       : type is light APC platoon.
#
# set-up      :       :       : creating ground unit open APC  .
# set-up      :       :       : type is open APC platoon.
#
# set-up      :       :       : creating ground unit infantry HQ  .
# set-up      :       :       : type is infantry HQ platoon.
#
# set-up      :       :       : creating ground unit mobile HQ  .
# set-up      :       :       : type is mobile HQ platoon.
#
# set-up      :       :       : creating ground unit armored HQ  .
# set-up      :       :       : type is armored HQ platoon.
#
# set-up      :       :       : creating ground unit armored mortar  .
# set-up      :       :       : type is armored mortar platoon.
#
# set-up      :       :       : creating ground unit towed mortar  .
# set-up      :       :       : type is towed mortar platoon.
#
# set-up      :       :       : creating ground unit light armored artillery   .
# set-up      :       :       : type is light armored artillery battery.
#
# set-up      :       :       : creating ground unit open armored artillery   .
# set-up      :       :       : type is open armored artillery battery.
#
# set-up      :       :       : creating ground unit tracked artillery   .
# set-up      :       :       : type is tracked artillery battery.
#
# set-up      :       :       : creating ground unit mobile artillery   .
# set-up      :       :       : type is mobile artillery battery.
#
# set-up      :       :       : creating ground unit towed artillery   .
# set-up      :       :       : type is towed artillery battery.
#
# set-up      :       :       : creating ground unit armored rocket artillery   .
# set-up      :       :       : type is armored rocket artillery battery.
#
# set-up      :       :       : creating ground unit mobile rocket artillery   .
# set-up      :       :       : type is mobile rocket artillery battery.
#
# set-up      :       :       : creating ground unit tracked missile artillery   .
# set-up      :       :       : type is tracked missile artillery battery.
#
# set-up      :       :       : creating ground unit mobile missile artillery   .
# set-up      :       :       : type is mobile missile artillery battery.
#
# set-up      :       :       : creating ground unit truck  .
# set-up      :       :       : type is truck platoon.
#
# set-up      :       :       : creating ground unit light truck  .
# set-up      :       :       : type is light truck platoon.
#
# set-up      :       :       : creating ground unit tracked carrier  .
# set-up      :       :       : type is tracked carrier platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['P']].
# set-up      : north is up.
# set-up      : map option style is 'temperate'.
# set-up      : map option dotsperhex is 80.
#
# set-up      :       :       : creating ground unit infantry
#   platoon.
# set-up      :       :       : type is infantry platoon.
#
# set-up      :       :       : creating ground unit infantry
#   weapons
#   platoon.
# set-up      :       :       : type is infantry weapons platoon.
#
# set-up      :       :       : creating ground unit infantry
#   mortar
#   platoon.
# set-up      :       :       : type is infantry mortar platoon.
#
# set-up      :       :       : creating ground unit infantry
#   FAC
#   squad.
# set-up      :       :       : type is infantry FAC squad.
#
# set-up      :       :       : creating ground unit infantry
#   SAM
#   squad.
# set-up      :       :       : type is infantry SAM squad.
#
# set-up      :       :       : creating ground unit infantry
#   heavy
#   SAM
#   squad.
# set-up      :       :       : type is infantry heavy SAM squad.
#
# set-up      :       :       : creating ground unit heavy
#   tank
#   platoon.
# set-up      :       :       : type is heavy tank platoon.
#
# set-up      :       :       : creating ground unit medium
#   tank
#   platoon.
# set-up      :       :       : type is medium tank platoon.
#
# set-up      :       :       : creating ground unit light
#   tank
#   platoon.
# set-up      :       :       : type is light tank platoon.
#
# set-up      :       :       : creating ground unit open
#   tank
#   platoon.
# set-up      :       :       : type is open tank platoon.
#
# set-up      :       :       : creating ground unit medium
#   anti-tank
#   platoon.
# set-up      :       :       : type is medium anti-tank platoon.
#
# set-up      :       :       : creating ground unit light
#   anti-tank
#   platoon.
# set-up      :       :       : type is light anti-tank platoon.
#
# set-up      :       :       : creating ground unit towed
#   anti-tank
#   battery.
# set-up      :       :       : type is towed anti-tank battery.
#
# set-up      :       :       : creating ground unit light
#   reconnaissance
#   platoon.
# set-up      :       :       : type is light reconnaissance platoon.
#
# set-up      :       :       : creating ground unit open
#   reconnaissance
#   platoon.
# set-up      :       :       : type is open reconnaissance platoon.
#
# set-up      :       :       : creating ground unit medium
#   IFV
#   platoon.
# set-up      :       :       : type is medium IFV platoon.
#
# set-up      :       :       : creating ground unit light
#   IFV
#   platoon.
# set-up      :       :       : type is light IFV platoon.
#
# set-up      :       :       : creating ground unit heavy
#   APC
#   platoon.
# set-up      :       :       : type is heavy APC platoon.
#
# set-up      :       :       : creating ground unit medium
#   APC
#   platoon.
# set-up      :       :       : type is medium APC platoon.
#
# set-up      :       :       : creating ground unit light
#   APC
#   platoon.
# set-up      :       :       : type is light APC platoon.
#
# set-up      :       :       : creating ground unit open
#   APC
#   platoon.
# set-up      :       :       : type is open APC platoon.
#
# set-up      :       :       : creating ground unit infantry
#   HQ
#   platoon.
# set-up      :       :       : type is infantry HQ platoon.
#
# set-up      :       :       : creating ground unit mobile
#   HQ
#   platoon.
# set-up      :       :       : type is mobile HQ platoon.
#
# set-up      :       :       : creating ground unit armored
#   HQ
#   platoon.
# set-up      :       :       : type is armored HQ platoon.
#
# set-up      :       :       : creating ground unit armored
#   mortar
#   platoon.
# set-up      :       :       : type is armored mortar platoon.
#
# set-up      :       :       : creating ground unit towed
#   mortar
#   platoon.
# set-up      :       :       : type is towed mortar platoon.
#
# set-up      :       :       : creating ground unit light
#   armored
#   artillery
#   battery.
# set-up      :       :       : type is light armored artillery battery.
#
# set-up      :       :       : creating ground unit open
#   armored
#   artillery
#   battery.
# set-up      :       :       : type is open armored artillery battery.
#
# set-up      :       :       : creating ground unit tracked
#   artillery
#   battery.
# set-up      :       :       : type is tracked artillery battery.
#
# set-up      :       :       : creating ground unit mobile
#   artillery
#   battery.
# set-up      :       :       : type is mobile artillery battery.
#
# set-up      :       :       : creating ground unit towed
#   artillery
#   battery.
# set-up      :       :       : type is towed artillery battery.
#
# set-up      :       :       : creating ground unit armored
#   rocket
#   artillery
#   battery.
# set-up      :       :       : type is armored rocket artillery battery.
#
# set-up      :       :       : creating ground unit mobile
#   rocket
#   artillery
#   battery.
# set-up      :       :       : type is mobile rocket artillery battery.
#
# set-up      :       :       : creating ground unit tracked
#   missile
#   artillery
#   battery.
# set-up      :       :       : type is tracked missile artillery battery.
#
# set-up      :       :       : creating ground unit mobile
#   missile
#   artillery
#   battery.
# set-up      :       :       : type is mobile missile artillery battery.
#
# set-up      :       :       : creating ground unit truck
#   platoon.
# set-up      :       :       : type is truck platoon.
#
# set-up      :       :       : creating ground unit light
#   truck
#   platoon.
# set-up      :       :       : type is light truck platoon.
#
# set-up      :       :       : creating ground unit tracked
#   carrier
#   platoon.
# set-up      :       :       : type is tracked carrier platoon.

# %%
for counter in [False, True]:

    startgamesetup(
        None,
        sheets=[["P"]],
        style="temperate",
        writelogfiles=False,
        dotsperhex=120,
    )

    x = 3
    y = 3

    for s in [
        "M2 platoon",
        "DShK-38 platoon",
        "M16 section",
        "M55 platoon",
        # "mobile M55 section",
        "ZPU-1 battery",
        "ZPU-2 battery",
        "ZPU-4 battery",
        "mobile ZPU-1 section",
        "mobile ZPU-2 section",
        "mobile ZPU-4 section",
        "TCM-20 platoon",
        "M3 TCM-20 section",
        "single Rh-202 battery",
        "twin Rh-202 battery",
        "Panhard M3 VDA section",
        "M163 section",
        "M167 platoon",
        "ZU-23 battery",
        "mobile ZU-23 section",
        "Sinai 23 Ayn-al-Saqr section",
        "Sinai 23 Stinger section",
        "ZSU-23-4 section",
        "LAV-AD section",
        "M53/59 section",
        "AMX-30SA section",
        "Tunguska section",
        "Tunguska-M section",
        # "Pantsir section",
        "Oerlikon GDF battery",
        "Oerlikon GDF section",
        "Gepard section",
        "61-K battery",
        "Bofors L/60 battery",
        "Bofors L/70 battery",
        "Bofors L/70 BOFI battery",
        "Bofors L/70 BOFI-R battery",
        "S-60 battery",
        "ZSU-57-2 section",
        "KS-12 battery",
        "KS-19 battery",
    ]:
        if s != "":
            if s.startswith("KS"):
                azimuth = "ENE"
            else:
                azimuth = None
            hexcode = "P-%02d%02d" % (x + 0, y)
            name = prettyname(s, counter)
            setupgroundunit(
                name, hexcode, s, azimuth=azimuth, color="lightgreen", identified=True, counter=counter,
            )
        if y == 10:
            x += 2
            y = 3
        else:
            y += 1

    drawmap(zoom=False, xmin=1.5, xmax=12.5, ymin=14.5, ymax=23.5)

# !mv map-00.png figure-aaa.png
# Out:
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['P']].
# set-up      : north is up.
# set-up      : map option style is 'temperate'.
# set-up      : map option dotsperhex is 120.
#
# set-up      :       :       : creating ground unit M2  .
# set-up      :       :       : type is M2 platoon.
#
# set-up      :       :       : creating ground unit DShK-38  .
# set-up      :       :       : type is DShK-38 platoon.
#
# set-up      :       :       : creating ground unit M16 .
# set-up      :       :       : type is M16 section.
#
# set-up      :       :       : creating ground unit M55  .
# set-up      :       :       : type is M55 platoon.
#
# set-up      :       :       : creating ground unit ZPU-1   .
# set-up      :       :       : type is ZPU-1 battery.
#
# set-up      :       :       : creating ground unit ZPU-2   .
# set-up      :       :       : type is ZPU-2 battery.
#
# set-up      :       :       : creating ground unit ZPU-4   .
# set-up      :       :       : type is ZPU-4 battery.
#
# set-up      :       :       : creating ground unit mobile ZPU-1 .
# set-up      :       :       : type is mobile ZPU-1 section.
#
# set-up      :       :       : creating ground unit mobile ZPU-2 .
# set-up      :       :       : type is mobile ZPU-2 section.
#
# set-up      :       :       : creating ground unit mobile ZPU-4 .
# set-up      :       :       : type is mobile ZPU-4 section.
#
# set-up      :       :       : creating ground unit TCM-20  .
# set-up      :       :       : type is TCM-20 platoon.
#
# set-up      :       :       : creating ground unit M3 TCM-20 .
# set-up      :       :       : type is M3 TCM-20 section.
#
# set-up      :       :       : creating ground unit single Rh-202   .
# set-up      :       :       : type is single Rh-202 battery.
#
# set-up      :       :       : creating ground unit twin Rh-202   .
# set-up      :       :       : type is twin Rh-202 battery.
#
# set-up      :       :       : creating ground unit Panhard M3 VDA .
# set-up      :       :       : type is Panhard M3 VDA section.
#
# set-up      :       :       : creating ground unit M163 .
# set-up      :       :       : type is M163 section.
#
# set-up      :       :       : creating ground unit M167  .
# set-up      :       :       : type is M167 platoon.
#
# set-up      :       :       : creating ground unit ZU-23   .
# set-up      :       :       : type is ZU-23 battery.
#
# set-up      :       :       : creating ground unit mobile ZU-23 .
# set-up      :       :       : type is mobile ZU-23 section.
#
# set-up      :       :       : creating ground unit Sinai 23 Ayn-al-Saqr .
# set-up      :       :       : type is Sinai 23 Ayn-al-Saqr section.
#
# set-up      :       :       : creating ground unit Sinai 23 Stinger .
# set-up      :       :       : type is Sinai 23 Stinger section.
#
# set-up      :       :       : creating ground unit ZSU-23-4 .
# set-up      :       :       : type is ZSU-23-4 section.
#
# set-up      :       :       : creating ground unit LAV-AD .
# set-up      :       :       : type is LAV-AD section.
#
# set-up      :       :       : creating ground unit M53/59 .
# set-up      :       :       : type is M53/59 section.
#
# set-up      :       :       : creating ground unit AMX-30SA .
# set-up      :       :       : type is AMX-30SA section.
#
# set-up      :       :       : creating ground unit Tunguska .
# set-up      :       :       : type is Tunguska section.
#
# set-up      :       :       : creating ground unit Tunguska-M .
# set-up      :       :       : type is Tunguska-M section.
#
# set-up      :       :       : creating ground unit Oerlikon GDF   .
# set-up      :       :       : type is Oerlikon GDF battery.
#
# set-up      :       :       : creating ground unit Oerlikon GDF .
# set-up      :       :       : type is Oerlikon GDF section.
#
# set-up      :       :       : creating ground unit Gepard .
# set-up      :       :       : type is Gepard section.
#
# set-up      :       :       : creating ground unit 61-K   .
# set-up      :       :       : type is 61-K battery.
#
# set-up      :       :       : creating ground unit Bofors L/60   .
# set-up      :       :       : type is Bofors L/60 battery.
#
# set-up      :       :       : creating ground unit Bofors L/70   .
# set-up      :       :       : type is Bofors L/70 battery.
#
# set-up      :       :       : creating ground unit Bofors L/70 BOFI   .
# set-up      :       :       : type is Bofors L/70 BOFI battery.
#
# set-up      :       :       : creating ground unit Bofors L/70 BOFI-R   .
# set-up      :       :       : type is Bofors L/70 BOFI-R battery.
#
# set-up      :       :       : creating ground unit S-60   .
# set-up      :       :       : type is S-60 battery.
#
# set-up      :       :       : creating ground unit ZSU-57-2 .
# set-up      :       :       : type is ZSU-57-2 section.
#
# set-up      :       :       : creating ground unit KS-12   .
# set-up      :       :       : type is KS-12 battery.
#
# set-up      :       :       : creating ground unit KS-19   .
# set-up      :       :       : type is KS-19 battery.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['P']].
# set-up      : north is up.
# set-up      : map option style is 'temperate'.
# set-up      : map option dotsperhex is 120.
#
# set-up      :       :       : creating ground unit M2
#   platoon.
# set-up      :       :       : type is M2 platoon.
#
# set-up      :       :       : creating ground unit DShK-38
#   platoon.
# set-up      :       :       : type is DShK-38 platoon.
#
# set-up      :       :       : creating ground unit M16
#   section.
# set-up      :       :       : type is M16 section.
#
# set-up      :       :       : creating ground unit M55
#   platoon.
# set-up      :       :       : type is M55 platoon.
#
# set-up      :       :       : creating ground unit ZPU-1
#   battery.
# set-up      :       :       : type is ZPU-1 battery.
#
# set-up      :       :       : creating ground unit ZPU-2
#   battery.
# set-up      :       :       : type is ZPU-2 battery.
#
# set-up      :       :       : creating ground unit ZPU-4
#   battery.
# set-up      :       :       : type is ZPU-4 battery.
#
# set-up      :       :       : creating ground unit mobile
#   ZPU-1
#   section.
# set-up      :       :       : type is mobile ZPU-1 section.
#
# set-up      :       :       : creating ground unit mobile
#   ZPU-2
#   section.
# set-up      :       :       : type is mobile ZPU-2 section.
#
# set-up      :       :       : creating ground unit mobile
#   ZPU-4
#   section.
# set-up      :       :       : type is mobile ZPU-4 section.
#
# set-up      :       :       : creating ground unit TCM-20
#   platoon.
# set-up      :       :       : type is TCM-20 platoon.
#
# set-up      :       :       : creating ground unit M3
#   TCM-20
#   section.
# set-up      :       :       : type is M3 TCM-20 section.
#
# set-up      :       :       : creating ground unit single
#   Rh-202
#   battery.
# set-up      :       :       : type is single Rh-202 battery.
#
# set-up      :       :       : creating ground unit twin
#   Rh-202
#   battery.
# set-up      :       :       : type is twin Rh-202 battery.
#
# set-up      :       :       : creating ground unit Panhard
#   M3
#   DCA
#   section.
# set-up      :       :       : type is Panhard M3 VDA section.
#
# set-up      :       :       : creating ground unit M163
#   section.
# set-up      :       :       : type is M163 section.
#
# set-up      :       :       : creating ground unit M167
#   platoon.
# set-up      :       :       : type is M167 platoon.
#
# set-up      :       :       : creating ground unit ZU-23
#   battery.
# set-up      :       :       : type is ZU-23 battery.
#
# set-up      :       :       : creating ground unit mobile
#   ZU-23
#   section.
# set-up      :       :       : type is mobile ZU-23 section.
#
# set-up      :       :       : creating ground unit Sinai
#   23
#   Ayn-al-Saqr
#   section.
# set-up      :       :       : type is Sinai 23 Ayn-al-Saqr section.
#
# set-up      :       :       : creating ground unit Sinai
#   23
#   Stinger
#   section.
# set-up      :       :       : type is Sinai 23 Stinger section.
#
# set-up      :       :       : creating ground unit ZSU-23-4
#   section.
# set-up      :       :       : type is ZSU-23-4 section.
#
# set-up      :       :       : creating ground unit LAV-AD
#   section.
# set-up      :       :       : type is LAV-AD section.
#
# set-up      :       :       : creating ground unit M53/59
#   section.
# set-up      :       :       : type is M53/59 section.
#
# set-up      :       :       : creating ground unit AMX-30SA
#   section.
# set-up      :       :       : type is AMX-30SA section.
#
# set-up      :       :       : creating ground unit Tunguska
#   section.
# set-up      :       :       : type is Tunguska section.
#
# set-up      :       :       : creating ground unit Tunguska-M
#   section.
# set-up      :       :       : type is Tunguska-M section.
#
# set-up      :       :       : creating ground unit Oerlikon
#   GDF
#   battery.
# set-up      :       :       : type is Oerlikon GDF battery.
#
# set-up      :       :       : creating ground unit Oerlikon
#   GDF
#   section.
# set-up      :       :       : type is Oerlikon GDF section.
#
# set-up      :       :       : creating ground unit Gepard
#   section.
# set-up      :       :       : type is Gepard section.
#
# set-up      :       :       : creating ground unit 61-K
#   battery.
# set-up      :       :       : type is 61-K battery.
#
# set-up      :       :       : creating ground unit Bofors
#   L/60
#   battery.
# set-up      :       :       : type is Bofors L/60 battery.
#
# set-up      :       :       : creating ground unit Bofors
#   L/70
#   battery.
# set-up      :       :       : type is Bofors L/70 battery.
#
# set-up      :       :       : creating ground unit Bofors
#   L/70
#   BOFI
#   battery.
# set-up      :       :       : type is Bofors L/70 BOFI battery.
#
# set-up      :       :       : creating ground unit Bofors
#   L/70
#   BOFI-R
#   battery.
# set-up      :       :       : type is Bofors L/70 BOFI-R battery.
#
# set-up      :       :       : creating ground unit S-60
#   battery.
# set-up      :       :       : type is S-60 battery.
#
# set-up      :       :       : creating ground unit ZSU-57-2
#   section.
# set-up      :       :       : type is ZSU-57-2 section.
#
# set-up      :       :       : creating ground unit KS-12
#   battery.
# set-up      :       :       : type is KS-12 battery.
#
# set-up      :       :       : creating ground unit KS-19
#   battery.
# set-up      :       :       : type is KS-19 battery.

# %%
for counter in [False, True]:

    startgamesetup(
        None,
        sheets=[["P"]],
        style="temperate",
        writelogfiles=False,
        dotsperhex=120,
    )

    x = 3
    y = 3

    for s in [
        "towed FCR-A platoon",
        "towed FCR-B platoon",
        "towed FCR-C platoon",
        "towed FCR-D platoon",
        "mobile EWR-A platoon",
        "mobile EWR-B platoon",
        "mobile CCU platoon",
        "armored CCU squad",
        "Crotale CCU/EWR squad",
        ""
    ]:
        if s != "":
            hexcode = "P-%02d%02d" % (x + 0, y)
            name = prettyname(s, counter)
            setupgroundunit(name, hexcode, s, color="lightgreen", counter=counter, identified=True)
        if y == 4:
            x += 2
            y = 3
        else:
            y += 1

    drawmap(zoom=False, xmin=1.5, xmax=12.5, ymin=20.5, ymax=23.5)

# !mv map-00.png figure-radar-and-ccu-units.png
# Out:
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['P']].
# set-up      : north is up.
# set-up      : map option style is 'temperate'.
# set-up      : map option dotsperhex is 120.
#
# set-up      :       :       : creating ground unit towed FCR-A  .
# set-up      :       :       : type is towed FCR-A platoon.
#
# set-up      :       :       : creating ground unit towed FCR-B  .
# set-up      :       :       : type is towed FCR-B platoon.
#
# set-up      :       :       : creating ground unit towed FCR-C  .
# set-up      :       :       : type is towed FCR-C platoon.
#
# set-up      :       :       : creating ground unit towed FCR-D  .
# set-up      :       :       : type is towed FCR-D platoon.
#
# set-up      :       :       : creating ground unit mobile EWR-A  .
# set-up      :       :       : type is mobile EWR-A platoon.
#
# set-up      :       :       : creating ground unit mobile EWR-B  .
# set-up      :       :       : type is mobile EWR-B platoon.
#
# set-up      :       :       : creating ground unit mobile CCU  .
# set-up      :       :       : type is mobile CCU platoon.
#
# set-up      :       :       : creating ground unit armored CCU.
# set-up      :       :       : type is armored CCU squad.
#
# set-up      :       :       : creating ground unit Crotale CCU/EWR.
# set-up      :       :       : type is Crotale CCU/EWR squad.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['P']].
# set-up      : north is up.
# set-up      : map option style is 'temperate'.
# set-up      : map option dotsperhex is 120.
#
# set-up      :       :       : creating ground unit towed
#   FCR-A
#   platoon.
# set-up      :       :       : type is towed FCR-A platoon.
#
# set-up      :       :       : creating ground unit towed
#   FCR-B
#   platoon.
# set-up      :       :       : type is towed FCR-B platoon.
#
# set-up      :       :       : creating ground unit towed
#   FCR-C
#   platoon.
# set-up      :       :       : type is towed FCR-C platoon.
#
# set-up      :       :       : creating ground unit towed
#   FCR-D
#   platoon.
# set-up      :       :       : type is towed FCR-D platoon.
#
# set-up      :       :       : creating ground unit mobile
#   EWR-A
#   platoon.
# set-up      :       :       : type is mobile EWR-A platoon.
#
# set-up      :       :       : creating ground unit mobile
#   EWR-B
#   platoon.
# set-up      :       :       : type is mobile EWR-B platoon.
#
# set-up      :       :       : creating ground unit mobile
#   CCU
#   platoon.
# set-up      :       :       : type is mobile CCU platoon.
#
# set-up      :       :       : creating ground unit armored
#   CCU
#   squad.
# set-up      :       :       : type is armored CCU squad.
#
# set-up      :       :       : creating ground unit Crotale
#   CCU/EWR
#   squad.
# set-up      :       :       : type is Crotale CCU/EWR squad.

# %%
for counter in [False, True]:

    startgamesetup(
        None,
        sheets=[["P"]],
        style="temperate",
        writelogfiles=False,
        dotsperhex=120,
    )

    x = 3
    y = 3

    for s in [
        "SA-7A squad",
        "SA-7B squad",
        "SA-14 squad",
        "SA-16 squad",
        "SA-18 squad",
        "",
        "FIM-43C squad",
        "FIM-92A squad",
        "FIM-92B squad",
        "FIM-92C squad",
        "FIM-92D squad",
        "",
        "Blowpipe squad",
        "Javelin squad",
        "Starburst squad",
        "Starstreak squad",
        "Starstreak LML squad",
        "",
        "Mistral squad",
        "RBS 70 squad",
        "Ayn-al-Saqr squad",
        "",
    ]:
        if s != "":
            hexcode = "P-%02d%02d" % (x + 0, y)
            name = prettyname(s, counter)
            setupgroundunit(name, hexcode, s, color="lightgreen", counter=counter, identified=True)
        if y == 8:
            x += 2
            y = 3
        else:
            y += 1

    drawmap(zoom=False, xmin=1.5, xmax=12.5, ymin=16.5, ymax=23.5)

# !mv map-00.png figure-infantry-sam-units.png
# Out:
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['P']].
# set-up      : north is up.
# set-up      : map option style is 'temperate'.
# set-up      : map option dotsperhex is 120.
#
# set-up      :       :       : creating ground unit SA-7A.
# set-up      :       :       : type is SA-7A squad.
#
# set-up      :       :       : creating ground unit SA-7B.
# set-up      :       :       : type is SA-7B squad.
#
# set-up      :       :       : creating ground unit SA-14.
# set-up      :       :       : type is SA-14 squad.
#
# set-up      :       :       : creating ground unit SA-16.
# set-up      :       :       : type is SA-16 squad.
#
# set-up      :       :       : creating ground unit SA-18.
# set-up      :       :       : type is SA-18 squad.
#
# set-up      :       :       : creating ground unit FIM-43C.
# set-up      :       :       : type is FIM-43C squad.
#
# set-up      :       :       : creating ground unit FIM-92A.
# set-up      :       :       : type is FIM-92A squad.
#
# set-up      :       :       : creating ground unit FIM-92B.
# set-up      :       :       : type is FIM-92B squad.
#
# set-up      :       :       : creating ground unit FIM-92C.
# set-up      :       :       : type is FIM-92C squad.
#
# set-up      :       :       : creating ground unit FIM-92D.
# set-up      :       :       : type is FIM-92D squad.
#
# set-up      :       :       : creating ground unit Blowpipe.
# set-up      :       :       : type is Blowpipe squad.
#
# set-up      :       :       : creating ground unit Javelin.
# set-up      :       :       : type is Javelin squad.
#
# set-up      :       :       : creating ground unit Starburst.
# set-up      :       :       : type is Starburst squad.
#
# set-up      :       :       : creating ground unit Starstreak.
# set-up      :       :       : type is Starstreak squad.
#
# set-up      :       :       : creating ground unit Starstreak LML.
# set-up      :       :       : type is Starstreak LML squad.
#
# set-up      :       :       : creating ground unit Mistral.
# set-up      :       :       : type is Mistral squad.
#
# set-up      :       :       : creating ground unit RBS 70.
# set-up      :       :       : type is RBS 70 squad.
#
# set-up      :       :       : creating ground unit Ayn-al-Saqr.
# set-up      :       :       : type is Ayn-al-Saqr squad.

# %%
for counter in [False, True]:

    startgamesetup(
        None,
        sheets=[["P"]],
        style="temperate",
        writelogfiles=False,
        dotsperhex=120,
    )

    x = 3
    y = 3

    for s in [
        "SA-2B battery",
        "SA-2C battery",
        "SA-2E battery",
        "SA-2F battery",
        "SA-3B battery",
        "mobile SA-3B battery",
        "SA-4A battery",
        "SA-4B battery",
        "SA-6A battery",
        "SA-6B battery",
        "SA-8A squad",
        "SA-8B squad",
        "SA-9A squad",
        "SA-9B squad",
        "SA-11 squad",
        "SA-13 squad",
        #"SA-5 battery",
        #"SA-10A battery",
        #"SA-10B battery",
        #"SA-12A battery",
        #"SA-12B battery",
        #"SA-13 squad",
        #"SA-15 squad",
        #"SA-17 squad",
        #"Tunguska section",
        #"Pantsir section",
        "M48 squad",
        "I-HAWK platoon",
        "MIM-104A battery",
    ]:
        if s != "":
            hexcode = "P-%02d%02d" % (x + 0, y)
            name = prettyname(s, counter)
            setupgroundunit(name, hexcode, s, color="lightgreen", counter=counter, identified=True)
        if y == 8:
            x += 2
            y = 3
        else:
            y += 1

    drawmap(zoom=False, xmin=1.5, xmax=12.5, ymin=16.5, ymax=23.5)

# !mv map-00.png figure-sam-launcher.png

# %%
for counter in [False, True]:

    startgamesetup(
        None,
        sheets=[["P"]],
        style="temperate",
        writelogfiles=False,
        dotsperhex=120,
    )

    x = 3
    y = 3

    for s in [
        "locomotive",
        "railcar",
        "POL",
        "supplies",
        "small building",
        "large building",
        "factory",
        "power station",
        "bunker entrance",
        "hanger",
        "shelter",
        "tower",
        "transport airplane",
        "fighter airplane",
        "helicopter",
        "barge",
        "junk",
        "pontoon bridge",
    ]:
        if s != "":
            hexcode = "P-%02d%02d" % (x + 0, y)
            name = prettyname(s, counter)
            setupgroundunit(name, hexcode, s, color="lightgreen", counter=counter, identified=True)
        if y == 6:
            x += 2
            y = 3
        else:
            y += 1

    drawmap(zoom=False, xmin=1.5, xmax=12.5, ymin=18.5, ymax=23.5)

# !mv map-00.png figure-ground-targets.png

# %%
startgamesetup(
    None,
    sheets=[["F"]],
    style="temperateplain",
    writelogfiles=False,
    dotsperhex=300,
    levelincrement=0,
)

# endgamesetup()
# startgameturn()

drawmap(zoom=False, xmin=0.5, xmax=8.5, ymin=17, ymax=24)
import glass.draw

for x, y, label in [
    [1, 23.5, "H/U"],
    [1, 22.5, "H/U"],
    [1, 21.5, "H/U"],
    [1, 20.5, "L/H/U"],
    [1, 19.5, "U"],
    [1, 18.5, "U"],
    [1, 17.5, "H/U"],
    [2, 23.0, "U"],
    [2, 22.0, "U"],
    [2, 21.0, "L/H/U"],
    [2, 20.0, "U"],
    [2, 19.0, "U"],
    [2, 18.0, ""],
    [3, 23.5, "U"],
    [3, 22.5, "U"],
    [3, 21.5, "L/H/U"],
    [3, 20.5, "U"],
    [3, 19.5, "U"],
    [3, 18.5, "H/U"],
    [3, 17.5, "H/U"],
    [4, 23.0, "U"],
    [4, 22.0, "L/H/U"],
    [4, 21.0, "U"],
    [4, 20.0, "U"],
    [4, 19.0, "U"],
    [4, 18.0, "U"],
    [5, 23.5, "L/H/U"],
    [5, 22.5, "L/H/U"],
    [5, 21.5, "U"],
    [5, 20.5, "U"],
    [5, 19.5, "U"],
    [5, 18.5, "U"],
    [5, 17.5, "H/U"],
    [6, 23.0, "L/H/U"],
    [6, 22.0, "L/H/U"],
    [6, 21.0, "U"],
    [6, 20.0, "H/U"],
    [6, 19.0, "H/U"],
    [6, 18.0, "H/U"],
    [7, 23.5, "H/U"],
    [7, 22.5, "L/H/U"],
    [7, 21.5, "L/H/U"],
    [7, 20.5, "L/H/U"],
    [7, 19.5, "H/U"],
    [7, 18.5, "H/U"],
    [7, 17.5, "H/U"],
    [8, 23.0, "H/U"],
    [8, 22.0, "L/H/U"],
    [8, 21.0, "L/H/U"],
    [8, 20.0, "L/H/U"],
    [8, 19.0, "H/U"],
    [8, 18.0, "H/U"],
]:
    if "L" in label:
        color = "natogreen"
    elif "H" in label:
        color = "natoyellow"
    elif "U" in label:
        color = "natored"
    else:
        color = "black"
    glass.draw._drawdotincanvas(
        *glass.draw._tocanvasxy(x, y), 0.1, fillcolor=color, linewidth="thin"
    )

glass.draw.writecanvastofile("figure-mobility.png")
