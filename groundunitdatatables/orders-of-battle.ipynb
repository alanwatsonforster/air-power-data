# %%
import sys
sys.path.append("../../glass/src")

# %%
import glass
import glass.draw

import math

# !mkdir -p orders-of-battle

def drawstart(rows):
    glass.startgamesetup(None, sheets=[["A"]], writelogfiles=False)

    groundunitcountersize = 0.6 * math.sqrt(4 / 3)
    dotspercounter = 300
    dotsperhex = dotspercounter / groundunitcountersize

    minx = 0
    miny = 0
    maxx = 7
    maxy = rows - 1

    glass.draw.startcanvas(
        minx - 0.5 * math.sqrt(4/3),
        miny - 0.5,
        maxx + 0.5 * math.sqrt(4/3),
        maxy + 0.5,
        dotsperhex=dotsperhex,
    )

def drawcounter(
    x, y,
    type,
    name="", azimuth=None, 
):


    E = glass.setupgroundunit(
        name,
        type=type,
        hexcode=(x, y),
        color="white",
        counter=True,
        identified=True,
        azimuth=azimuth,
    )

    E._draw()
    
def drawend(filename):
    glass.draw.writecanvastofile("orders-of-battle/%s.png" % (filename))

# %%
battalion = 1
drawstart(5)
for company, y in zip(["A", "B", "C"], [2, 1, 0]):
    drawcounter(0, y, "medium tank platoon", name="1%s%s" %  (company, battalion))
    drawcounter(1, y, "medium tank platoon", name="2%s%s" %  (company, battalion))
    drawcounter(2, y, "medium tank platoon", name="3%s%s" %  (company, battalion))
    drawcounter(3, y, "heavy tank platoon", name="4%s%s" % (company, battalion))
drawcounter(0, 3, "light armored reconnaissance platoon", name="1R%s" % (battalion))
drawcounter(1, 3, "light armored reconnaissance platoon", name="2R%s" % (battalion))
drawcounter(2, 3, "light armored reconnaissance platoon", name="3R%s" % (battalion))
drawcounter(0, 4, "light armored HQ platoon", name="HQ%s" % (battalion))
drawend("british-armoured-regiment-early-1960s")
# Out:
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit 1A1.
# set-up      :       :       : type is medium tank platoon.
#
# set-up      :       :       : creating ground unit 2A1.
# set-up      :       :       : type is medium tank platoon.
#
# set-up      :       :       : creating ground unit 3A1.
# set-up      :       :       : type is medium tank platoon.
#
# set-up      :       :       : creating ground unit 4A1.
# set-up      :       :       : type is heavy tank platoon.
#
# set-up      :       :       : creating ground unit 1B1.
# set-up      :       :       : type is medium tank platoon.
#
# set-up      :       :       : creating ground unit 2B1.
# set-up      :       :       : type is medium tank platoon.
#
# set-up      :       :       : creating ground unit 3B1.
# set-up      :       :       : type is medium tank platoon.
#
# set-up      :       :       : creating ground unit 4B1.
# set-up      :       :       : type is heavy tank platoon.
#
# set-up      :       :       : creating ground unit 1C1.
# set-up      :       :       : type is medium tank platoon.
#
# set-up      :       :       : creating ground unit 2C1.
# set-up      :       :       : type is medium tank platoon.
#
# set-up      :       :       : creating ground unit 3C1.
# set-up      :       :       : type is medium tank platoon.
#
# set-up      :       :       : creating ground unit 4C1.
# set-up      :       :       : type is heavy tank platoon.
#
# set-up      :       :       : creating ground unit 1R1.
# set-up      :       :       : type is light armored reconnaissance platoon.
#
# set-up      :       :       : creating ground unit 2R1.
# set-up      :       :       : type is light armored reconnaissance platoon.
#
# set-up      :       :       : creating ground unit 3R1.
# set-up      :       :       : type is light armored reconnaissance platoon.
#
# set-up      :       :       : creating ground unit HQ1.
# set-up      :       :       : type is light armored HQ platoon.

# %%
battalion = 2
drawstart(4)
for company, y in zip(["A", "B", "C"], [2, 1, 0]):
    drawcounter(0, y, "infantry platoon", name="1%s%s" %  (company, battalion))
    drawcounter(1, y, "infantry platoon", name="2%s%s" %  (company, battalion))
    drawcounter(2, y, "infantry platoon", name="3%s%s" %  (company, battalion))
    drawcounter(3, y, "infantry weapons platoon", name="4%s%s" %  (company, battalion))
    drawcounter(4, y, "light APC platoon", name="T1%s%s" %  (company, battalion))
    drawcounter(5, y, "light APC platoon", name="T2%s%s" %  (company, battalion))
    drawcounter(6, y, "light APC platoon", name="T3%s%s" %  (company, battalion))
    drawcounter(7, y, "light APC platoon", name="T4%s%s" %  (company, battalion))
drawcounter(0, 3, "light armored HQ platoon", name="HQ%s" %  (battalion))
drawend("british-APC-infantry-battalion-early-1960s")
# Out:
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit 1A2.
# set-up      :       :       : type is infantry platoon.
#
# set-up      :       :       : creating ground unit 2A2.
# set-up      :       :       : type is infantry platoon.
#
# set-up      :       :       : creating ground unit 3A2.
# set-up      :       :       : type is infantry platoon.
#
# set-up      :       :       : creating ground unit 4A2.
# set-up      :       :       : type is infantry weapons platoon.
#
# set-up      :       :       : creating ground unit T1A2.
# set-up      :       :       : type is light APC platoon.
#
# set-up      :       :       : creating ground unit T2A2.
# set-up      :       :       : type is light APC platoon.
#
# set-up      :       :       : creating ground unit T3A2.
# set-up      :       :       : type is light APC platoon.
#
# set-up      :       :       : creating ground unit T4A2.
# set-up      :       :       : type is light APC platoon.
#
# set-up      :       :       : creating ground unit 1B2.
# set-up      :       :       : type is infantry platoon.
#
# set-up      :       :       : creating ground unit 2B2.
# set-up      :       :       : type is infantry platoon.
#
# set-up      :       :       : creating ground unit 3B2.
# set-up      :       :       : type is infantry platoon.
#
# set-up      :       :       : creating ground unit 4B2.
# set-up      :       :       : type is infantry weapons platoon.
#
# set-up      :       :       : creating ground unit T1B2.
# set-up      :       :       : type is light APC platoon.
#
# set-up      :       :       : creating ground unit T2B2.
# set-up      :       :       : type is light APC platoon.
#
# set-up      :       :       : creating ground unit T3B2.
# set-up      :       :       : type is light APC platoon.
#
# set-up      :       :       : creating ground unit T4B2.
# set-up      :       :       : type is light APC platoon.
#
# set-up      :       :       : creating ground unit 1C2.
# set-up      :       :       : type is infantry platoon.
#
# set-up      :       :       : creating ground unit 2C2.
# set-up      :       :       : type is infantry platoon.
#
# set-up      :       :       : creating ground unit 3C2.
# set-up      :       :       : type is infantry platoon.
#
# set-up      :       :       : creating ground unit 4C2.
# set-up      :       :       : type is infantry weapons platoon.
#
# set-up      :       :       : creating ground unit T1C2.
# set-up      :       :       : type is light APC platoon.
#
# set-up      :       :       : creating ground unit T2C2.
# set-up      :       :       : type is light APC platoon.
#
# set-up      :       :       : creating ground unit T3C2.
# set-up      :       :       : type is light APC platoon.
#
# set-up      :       :       : creating ground unit T4C2.
# set-up      :       :       : type is light APC platoon.
#
# set-up      :       :       : creating ground unit HQ2.
# set-up      :       :       : type is light armored HQ platoon.

# %%
battalion = 3
drawstart(4)
for company, y in zip(["A", "B", "C"], [2, 1, 0]):
    drawcounter(0, y, "infantry platoon", name="1%s%s" % (company, battalion))
    drawcounter(1, y, "infantry platoon", name="2%s%s" % (company, battalion))
    drawcounter(2, y, "infantry platoon", name="3%s%s" % (company, battalion))
    drawcounter(3, y, "infantry weapons platoon", name="4%s%s" % (company, battalion))
    drawcounter(4, y, "truck platoon", name="T1%s%s" % (company, battalion))
    drawcounter(5, y, "truck platoon", name="T2%s%s" % (company, battalion))
    drawcounter(6, y, "truck platoon", name="T3%s%s" % (company, battalion))
    drawcounter(7, y, "truck platoon", name="T4%s%s" % (company, battalion))
drawcounter(0, 3, "infantry HQ platoon", name="HQ%s" % battalion)
drawcounter(4, 3, "truck platoon", name="THQ%s" % (battalion))
drawend("british-infantry-battalion-early-1960s")
# Out:
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit 1A3.
# set-up      :       :       : type is infantry platoon.
#
# set-up      :       :       : creating ground unit 2A3.
# set-up      :       :       : type is infantry platoon.
#
# set-up      :       :       : creating ground unit 3A3.
# set-up      :       :       : type is infantry platoon.
#
# set-up      :       :       : creating ground unit 4A3.
# set-up      :       :       : type is infantry weapons platoon.
#
# set-up      :       :       : creating ground unit T1A3.
# set-up      :       :       : type is truck platoon.
#
# set-up      :       :       : creating ground unit T2A3.
# set-up      :       :       : type is truck platoon.
#
# set-up      :       :       : creating ground unit T3A3.
# set-up      :       :       : type is truck platoon.
#
# set-up      :       :       : creating ground unit T4A3.
# set-up      :       :       : type is truck platoon.
#
# set-up      :       :       : creating ground unit 1B3.
# set-up      :       :       : type is infantry platoon.
#
# set-up      :       :       : creating ground unit 2B3.
# set-up      :       :       : type is infantry platoon.
#
# set-up      :       :       : creating ground unit 3B3.
# set-up      :       :       : type is infantry platoon.
#
# set-up      :       :       : creating ground unit 4B3.
# set-up      :       :       : type is infantry weapons platoon.
#
# set-up      :       :       : creating ground unit T1B3.
# set-up      :       :       : type is truck platoon.
#
# set-up      :       :       : creating ground unit T2B3.
# set-up      :       :       : type is truck platoon.
#
# set-up      :       :       : creating ground unit T3B3.
# set-up      :       :       : type is truck platoon.
#
# set-up      :       :       : creating ground unit T4B3.
# set-up      :       :       : type is truck platoon.
#
# set-up      :       :       : creating ground unit 1C3.
# set-up      :       :       : type is infantry platoon.
#
# set-up      :       :       : creating ground unit 2C3.
# set-up      :       :       : type is infantry platoon.
#
# set-up      :       :       : creating ground unit 3C3.
# set-up      :       :       : type is infantry platoon.
#
# set-up      :       :       : creating ground unit 4C3.
# set-up      :       :       : type is infantry weapons platoon.
#
# set-up      :       :       : creating ground unit T1C3.
# set-up      :       :       : type is truck platoon.
#
# set-up      :       :       : creating ground unit T2C3.
# set-up      :       :       : type is truck platoon.
#
# set-up      :       :       : creating ground unit T3C3.
# set-up      :       :       : type is truck platoon.
#
# set-up      :       :       : creating ground unit T4C3.
# set-up      :       :       : type is truck platoon.
#
# set-up      :       :       : creating ground unit HQ3.
# set-up      :       :       : type is infantry HQ platoon.
#
# set-up      :       :       : creating ground unit THQ3.
# set-up      :       :       : type is truck platoon.

# %%
battalion = 4
drawstart(4)
for company, y in zip(["A", "B", "C", "D"], [3, 2, 1, 0]):
    drawcounter(0, y, "tracked artillery battery", name="%s%s" % (company, battalion))
drawcounter(0, 4, "mobile HQ platoon", name="HQ%s" % (battalion))
drawend("british-field-artillery-regiment-early-1960s")
# Out:
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit A4.
# set-up      :       :       : type is tracked artillery battery.
#
# set-up      :       :       : creating ground unit B4.
# set-up      :       :       : type is tracked artillery battery.
#
# set-up      :       :       : creating ground unit C4.
# set-up      :       :       : type is tracked artillery battery.
#
# set-up      :       :       : creating ground unit D4.
# set-up      :       :       : type is tracked artillery battery.
#
# set-up      :       :       : creating ground unit HQ4.
# set-up      :       :       : type is mobile HQ platoon.

# %%
battalion = 5
drawstart(5)
for company, y in zip(["A", "B"], [3, 2]):
    drawcounter(0, y, "mobile rocket artillery section", name="1%s%s" % (company, battalion))
for company, y in zip(["C", "D"], [1, 0]):
    drawcounter(0, y, "towed artillery battery", name="%s%s" % (company, battalion))
    drawcounter(4, y, "truck platoon", name="T%s%s" % (company, battalion))
drawcounter(0, 4, "mobile HQ platoon", name="HQ%s" % (battalion))
drawend("british-heavy-artillery-regiment-early-1960s")
# Out:
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit 1A5.
# set-up      :       :       : type is mobile rocket artillery section.
#
# set-up      :       :       : creating ground unit 1B5.
# set-up      :       :       : type is mobile rocket artillery section.
#
# set-up      :       :       : creating ground unit C5.
# set-up      :       :       : type is towed artillery battery.
#
# set-up      :       :       : creating ground unit TC5.
# set-up      :       :       : type is truck platoon.
#
# set-up      :       :       : creating ground unit D5.
# set-up      :       :       : type is towed artillery battery.
#
# set-up      :       :       : creating ground unit TD5.
# set-up      :       :       : type is truck platoon.
#
# set-up      :       :       : creating ground unit HQ5.
# set-up      :       :       : type is mobile HQ platoon.

# %%
battalion = 2
drawstart(7)
for company, y in zip(["A", "B", "D"], [3, 2, 0]):
    drawcounter(0, y, "infantry platoon", name="1%s%s" % (company, battalion))
    drawcounter(1, y, "infantry platoon", name="2%s%s" % (company, battalion))
    drawcounter(2, y, "infantry platoon", name="3%s%s" % (company, battalion))
for company, y in zip(["C"], [1]):
    drawcounter(0, y, "infantry platoon", name="1%s%s" % (company, battalion))
    drawcounter(1, y, "infantry platoon", name="2%s%s" % (company, battalion))
drawcounter(0, 4, "infantry mortar squad", name="1S%s" % (battalion))
drawcounter(1, 4, "infantry weapons platoon", name="2S%s" % (battalion))
drawcounter(2, 4, "infantry weapons platoon", name="3S%s" % (battalion))
drawcounter(3, 4, "infantry engineers platoon", name="4S%s" % (battalion))
drawcounter(0, 5, "towed artillery section", name="AR%s" % (battalion))
drawcounter(1, 5, "infantry engineers platoon", name="E%s" % (battalion))
drawcounter(2, 5, "Blowpipe squad", name="1AD%s" % (battalion))
drawcounter(3, 5, "Blowpipe squad", name="2AD%s" % (battalion))
drawcounter(0, 6, "infantry HQ platoon", name="HQ%s" % (battalion))
drawend("goose-green-2-para")
# Out:
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit 1A2.
# set-up      :       :       : type is infantry platoon.
#
# set-up      :       :       : creating ground unit 2A2.
# set-up      :       :       : type is infantry platoon.
#
# set-up      :       :       : creating ground unit 3A2.
# set-up      :       :       : type is infantry platoon.
#
# set-up      :       :       : creating ground unit 1B2.
# set-up      :       :       : type is infantry platoon.
#
# set-up      :       :       : creating ground unit 2B2.
# set-up      :       :       : type is infantry platoon.
#
# set-up      :       :       : creating ground unit 3B2.
# set-up      :       :       : type is infantry platoon.
#
# set-up      :       :       : creating ground unit 1D2.
# set-up      :       :       : type is infantry platoon.
#
# set-up      :       :       : creating ground unit 2D2.
# set-up      :       :       : type is infantry platoon.
#
# set-up      :       :       : creating ground unit 3D2.
# set-up      :       :       : type is infantry platoon.
#
# set-up      :       :       : creating ground unit 1C2.
# set-up      :       :       : type is infantry platoon.
#
# set-up      :       :       : creating ground unit 2C2.
# set-up      :       :       : type is infantry platoon.
#
# set-up      :       :       : creating ground unit 1S2.
# set-up      :       :       : type is infantry mortar squad.
#
# set-up      :       :       : creating ground unit 2S2.
# set-up      :       :       : type is infantry weapons platoon.
#
# set-up      :       :       : creating ground unit 3S2.
# set-up      :       :       : type is infantry weapons platoon.
#
# set-up      :       :       : creating ground unit 4S2.
# set-up      :       :       : type is infantry engineers platoon.
#
# set-up      :       :       : creating ground unit AR2.
# set-up      :       :       : type is towed artillery section.
#
# set-up      :       :       : creating ground unit E2.
# set-up      :       :       : type is infantry engineers platoon.
#
# set-up      :       :       : creating ground unit 1AD2.
# set-up      :       :       : type is Blowpipe squad.
#
# set-up      :       :       : creating ground unit 2AD2.
# set-up      :       :       : type is Blowpipe squad.
#
# set-up      :       :       : creating ground unit HQ2.
# set-up      :       :       : type is infantry HQ platoon.

# %%
battalion = 12
drawstart(6)



company = "A"
y = 3
drawcounter(0, y, "infantry platoon", name="1%s%s" % (company, battalion))
drawcounter(1, y, "infantry platoon", name="2%s%s" % (company, battalion))
drawcounter(2, y, "infantry platoon", name="3%s%s" % (company, battalion))
drawcounter(3, y, "infantry platoon", name="4%s%s" % (company, battalion))
drawcounter(4, y, "infantry platoon", name="5%s%s" % (company, battalion))

company = "B"
y = 2
drawcounter(0, y, "infantry platoon", name="1%s%s" % (company, battalion))
drawcounter(1, y, "infantry platoon", name="2%s%s" % (company, battalion))
drawcounter(2, y, "infantry platoon", name="3%s%s" % (company, battalion))


company = "C"
y = 1
drawcounter(0, y, "infantry platoon", name="1%s%s" % (company, battalion))
drawcounter(1, y, "infantry platoon", name="2%s%s" % (company, battalion))
drawcounter(2, y, "infantry weapons platoon", name="3%s%s" % (company, battalion))


battalion = 25
company = "C"
y = 0
drawcounter(0, y, "infantry platoon", name="1%s%s" % (company, battalion))
drawcounter(1, y, "infantry platoon", name="2%s%s" % (company, battalion))
drawcounter(2, y, "infantry weapons platoon", name="3%s%s" % (company, battalion))
battalion = 12

drawcounter(0, 4, "Oerlikon GDF section", name="1AD%s" % (battalion))
drawcounter(1, 4, "towed FCR-D platoon", name="2AD%s" % (battalion))
drawcounter(2, 4, "SA-7B squad", name="3AD%s" % (battalion))
drawcounter(3, 4, "SA-7B squad", name="4AD%s" % (battalion))
drawcounter(4, 4, "towed artillery section", name="AR%s" % (battalion))
drawcounter(5, 4, "infantry engineers platoon", name="E%s" % (battalion))

drawcounter(0, 5, "infantry HQ platoon", name="HQ%s" % (battalion))
drawend("goose-green-12-infantry-regiment")
# Out:
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit 1A12.
# set-up      :       :       : type is infantry platoon.
#
# set-up      :       :       : creating ground unit 2A12.
# set-up      :       :       : type is infantry platoon.
#
# set-up      :       :       : creating ground unit 3A12.
# set-up      :       :       : type is infantry platoon.
#
# set-up      :       :       : creating ground unit 4A12.
# set-up      :       :       : type is infantry platoon.
#
# set-up      :       :       : creating ground unit 5A12.
# set-up      :       :       : type is infantry platoon.
#
# set-up      :       :       : creating ground unit 1B12.
# set-up      :       :       : type is infantry platoon.
#
# set-up      :       :       : creating ground unit 2B12.
# set-up      :       :       : type is infantry platoon.
#
# set-up      :       :       : creating ground unit 3B12.
# set-up      :       :       : type is infantry platoon.
#
# set-up      :       :       : creating ground unit 1C12.
# set-up      :       :       : type is infantry platoon.
#
# set-up      :       :       : creating ground unit 2C12.
# set-up      :       :       : type is infantry platoon.
#
# set-up      :       :       : creating ground unit 3C12.
# set-up      :       :       : type is infantry weapons platoon.
#
# set-up      :       :       : creating ground unit 1C25.
# set-up      :       :       : type is infantry platoon.
#
# set-up      :       :       : creating ground unit 2C25.
# set-up      :       :       : type is infantry platoon.
#
# set-up      :       :       : creating ground unit 3C25.
# set-up      :       :       : type is infantry weapons platoon.
#
# set-up      :       :       : creating ground unit 1AD12.
# set-up      :       :       : type is Oerlikon GDF section.
#
# set-up      :       :       : creating ground unit 2AD12.
# set-up      :       :       : type is towed FCR-D platoon.
#
# set-up      :       :       : creating ground unit 3AD12.
# set-up      :       :       : type is SA-7B squad.
#
# set-up      :       :       : creating ground unit 4AD12.
# set-up      :       :       : type is SA-7B squad.
#
# set-up      :       :       : creating ground unit AR12.
# set-up      :       :       : type is towed artillery section.
#
# set-up      :       :       : creating ground unit E12.
# set-up      :       :       : type is infantry engineers platoon.
#
# set-up      :       :       : creating ground unit HQ12.
# set-up      :       :       : type is infantry HQ platoon.

# %%
battalion = "C"
drawstart(2)

company = "S"
drawcounter(0, 0, "infantry platoon", name="1%s%s" % (company, battalion))

drawcounter(0, 1, "Twin Rh-202 battery", name="1AD%s" % (battalion))
drawcounter(1, 1, "mobile EWR-B platoon", name="2AD%s" % (battalion))

drawend("goose-green-airbase-condor")
# Out:
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit 1SC.
# set-up      :       :       : type is infantry platoon.
#
# set-up      :       :       : creating ground unit 1ADC.
# set-up      :       :       : type is Twin Rh-202 battery.
#
# set-up      :       :       : creating ground unit 2ADC.
# set-up      :       :       : type is mobile EWR-B platoon.

# %%
battalion = 1
drawstart(6)
for company, y in zip(["A", "B", "C"], [2, 1, 0]):
    drawcounter(0, y, "heavy tank platoon", name="1%s%s" %  (company, battalion))
    drawcounter(1, y, "heavy tank platoon", name="2%s%s" %  (company, battalion))
    drawcounter(2, y, "heavy tank platoon", name="3%s%s" %  (company, battalion))
    drawcounter(3, y, "heavy tank platoon", name="4%s%s" % (company, battalion))
drawcounter(0, 3, "light armored anti-tank missile platoon", name="1AT%s" % (battalion))
drawcounter(1, 3, "light armored anti-tank missile platoon", name="2AT%s" % (battalion))
drawcounter(2, 3, "light armored anti-tank missile platoon", name="3AT%s" % (battalion))
drawcounter(0, 4, "light armored reconnaissance platoon", name="1R%s" % (battalion))
drawcounter(1, 4, "light armored reconnaissance platoon", name="2R%s" % (battalion))
drawcounter(0, 5, "light armored HQ platoon", name="HQ%s" % (battalion))
drawend("british-armoured-regiment-mid-1980s")
# Out:
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit 1A1.
# set-up      :       :       : type is heavy tank platoon.
#
# set-up      :       :       : creating ground unit 2A1.
# set-up      :       :       : type is heavy tank platoon.
#
# set-up      :       :       : creating ground unit 3A1.
# set-up      :       :       : type is heavy tank platoon.
#
# set-up      :       :       : creating ground unit 4A1.
# set-up      :       :       : type is heavy tank platoon.
#
# set-up      :       :       : creating ground unit 1B1.
# set-up      :       :       : type is heavy tank platoon.
#
# set-up      :       :       : creating ground unit 2B1.
# set-up      :       :       : type is heavy tank platoon.
#
# set-up      :       :       : creating ground unit 3B1.
# set-up      :       :       : type is heavy tank platoon.
#
# set-up      :       :       : creating ground unit 4B1.
# set-up      :       :       : type is heavy tank platoon.
#
# set-up      :       :       : creating ground unit 1C1.
# set-up      :       :       : type is heavy tank platoon.
#
# set-up      :       :       : creating ground unit 2C1.
# set-up      :       :       : type is heavy tank platoon.
#
# set-up      :       :       : creating ground unit 3C1.
# set-up      :       :       : type is heavy tank platoon.
#
# set-up      :       :       : creating ground unit 4C1.
# set-up      :       :       : type is heavy tank platoon.
#
# set-up      :       :       : creating ground unit 1AT1.
# set-up      :       :       : type is light armored anti-tank missile platoon.
#
# set-up      :       :       : creating ground unit 2AT1.
# set-up      :       :       : type is light armored anti-tank missile platoon.
#
# set-up      :       :       : creating ground unit 3AT1.
# set-up      :       :       : type is light armored anti-tank missile platoon.
#
# set-up      :       :       : creating ground unit 1R1.
# set-up      :       :       : type is light armored reconnaissance platoon.
#
# set-up      :       :       : creating ground unit 2R1.
# set-up      :       :       : type is light armored reconnaissance platoon.
#
# set-up      :       :       : creating ground unit HQ1.
# set-up      :       :       : type is light armored HQ platoon.
