# %%
import glass
import glass.draw

import math
import os

# !mkdir counters

def drawcounter(
    type, color="white", sighted=False, identified=False, azimuth=None, protectionclass=None
):

    glass.startgamesetup(None, sheets=[["A"]], writelogfiles=False)

    E = glass.setupgroundunit(
        "",
        type=type,
        hexcode="origin",
        color=color,
        counter=True,
        sighted=sighted,
        identified=identified,
        azimuth=azimuth
    )

    groundunitcountersize = 0.6 * math.sqrt(4 / 3)
    dotspercounter = 300
    dotsperhex = dotspercounter / groundunitcountersize

    glass.draw.startcanvas(
        -0.51 * groundunitcountersize * math.sqrt(4/3),
        -0.51 * groundunitcountersize,
        +0.51 * groundunitcountersize * math.sqrt(4/3),
        +0.51 * groundunitcountersize,
        dotsperhex=dotsperhex,
    )

    E._draw()

    glass.draw.writecanvastofile("counters/%s.png" % (type))


drawcounter("infantry platoon", identified=True)
# Out:
# mkdir: counters: File exists
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is infantry platoon.

# %%
os.system("rm -rf counters/")
os.system("mkdir -p counters/")

color = "white"

for name in [

    "infantry platoon",
    "infantry weapons platoon",
    "infantry mortar platoon",
    "infantry FAC squad",
    "infantry SAM squad",
    "infantry heavy SAM squad",
    "infantry HQ platoon",


    "heavy tank platoon",
    "medium tank platoon",
    "light tank platoon",
    "open tank platoon",
    "medium anti-tank missile platoon",
    "light anti-tank missile platoon",
    "light reconnaissance platoon",
    "open reconnaissance platoon",
    "medium IFV platoon",
    "light IFV platoon",
    "heavy APC platoon",
    "medium APC platoon",
    "light APC platoon",
    "open APC platoon",
    "light armored mortar platoon",
    "light armored artillery battery",
    "open armored artillery battery",
    "light armored rocket artillery battery",
    "light armored HQ platoon",


    "truck platoon",
    "light truck platoon",
    "tracked carrier platoon",
    "mobile artillery battery",
    "tracked artillery battery",
    "mobile rocket artillery battery",
    "tracked missile artillery battery",
    "mobile missile artillery battery",
    "mobile HQ platoon",


    "towed anti-tank gun battery",
    "towed mortar platoon",
    "towed artillery battery",

    "FCR-A platoon",
    "FCR-B platoon",
    "FCR-C platoon",
    "FCR-D platoon",
    "towed EWR-A",
    "mobile EWR-A",
    "mobile CCU section",
    "armored CCU section",

    "M2 platoon",
    "DShK-38 platoon",
    "M16 section",
    "M55 battery",
    # "mobile M55 section",
    "ZPU-1 battery",
    "ZPU-2 battery",
    "ZPU-4 battery",
    "mobile ZPU-4 section",
    "TCM-20 battery",
    "M3 TCM-20 section",
    "Rh-202 battery",
    "Panhard M3 DCA section",
    "M163 section",
    "M167 battery",
    "ZU-23 battery",
    "mobile ZU-23 section",
    "ZSU-23-4 section",
    "LAV-AD section",
    "M5359 section",
    "AMX-30SA section",
    "Tunguska section",
    "Tunguska-M section",
    # "Pantsir section",
    "Oerlikon GDF battery",
    "Gepard section",
    "61-K battery",
    "Bofors L60 battery",
    "Bofors L70 battery",
    "Bofors L70 BOFI battery",
    "Bofors L70 BOFI-R battery",
    "S-60 battery",

    "SA-2B battery",
    "SA-2C battery",
    "SA-2E battery",
    "SA-2F battery",
    "SA-3B battery",
    "mobile SA-3B battery",
    "SA-4A battery",
    "SA-4B battery",
    "SA-6A battery",
    "SA-6B battery",
    "SA-7A section",
    "SA-7B section",
    "SA-8A squad",
    "SA-8B squad",
    "SA-9A squad",
    "SA-9B squad",
    "SA-11 squad",
    "SA-13 squad",
    "SA-14 section",
    #"SA-5 battery",
    #"SA-10A battery",
    #"SA-10B battery",
    #"SA-12A battery",
    #"SA-12B battery",
    #"SA-13 squad",
    #"SA-15 squad",
    #"SA-17 squad",
    #"Tunguska section",
    #"Pantsir section",
    "M48 squad",
    "I-HAWK platoon",
    "MIM-104A battery",
]:
    drawcounter(name, color=color, identified=True)
for name in [
    "KS-12 battery",
    "KS-19 battery",
    ]:
    drawcounter(name, color=color, identified=True, azimuth=0)
for name in [
    "unidentified air-defense 12",
    "unidentified air-defense 18",
    "unidentified armor",
    "unidentified artillery",
    "unidentified infantry",
    "unidentified radar",
    "unidentified truck",
]:
    drawcounter(name, color=color, sighted=True)
for name in [
"unsighted",
]:
    drawcounter(name, color=color)
# Out:
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is infantry platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is infantry weapons platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is infantry mortar platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is infantry FAC squad.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is infantry SAM squad.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is infantry heavy SAM squad.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is infantry HQ platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is heavy tank platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is medium tank platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is light tank platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is open tank platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is medium anti-tank missile platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is light anti-tank missile platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is light reconnaissance platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is open reconnaissance platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is medium IFV platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is light IFV platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is heavy APC platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is medium APC platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is light APC platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is open APC platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is light armored mortar platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is light armored artillery battery.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is open armored artillery battery.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is light armored rocket artillery battery.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is light armored HQ platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is truck platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is light truck platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is tracked carrier platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is mobile artillery battery.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is tracked artillery battery.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is mobile rocket artillery battery.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is tracked missile artillery battery.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is mobile missile artillery battery.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is mobile HQ platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is towed anti-tank gun battery.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is towed mortar platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is towed artillery battery.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is FCR-A platoon.
#
# === ERROR: unable to find the groundunitdata file "FCR-A platoon". ===
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 128
#       4 color = "white"
#       6 for name in [
#       7
#       8     "infantry platoon",
#    (...)    126     "MIM-104A battery",
#     127 ]:
# --> 128     drawcounter(name, color=color, identified=True)
#     129 for name in [
#     130     "KS-12 battery",
#     131     "KS-19 battery",
#     132     ]:
#     133     drawcounter(name, color=color, identified=True, azimuth=0)
#
# Cell In[9], line 38, in drawcounter(type, color, sighted, identified, azimuth, protectionclass)
#      28 dotsperhex = dotspercounter / groundunitcountersize
#      30 glass.draw.startcanvas(
#      31     -0.51 * groundunitcountersize * math.sqrt(4/3),
#      32     -0.51 * groundunitcountersize,
#    (...)     35     dotsperhex=dotsperhex,
#      36 )
# ---> 38 E._draw()
#      40 glass.draw.writecanvastofile("counters/%s.png" % (type))
#
# File ~/GitHub/Home/glass/src/glass/groundunit/draw.py:10, in _draw(self, allsighted, allidentified, **kwargs)
#       8 def _draw(self, allsighted=False, allidentified=False, **kwargs):
# ---> 10     if self.istransported():
#      11         return
#      13     if self.isidentified() and self.istowing():
#
# File ~/GitHub/Home/glass/src/glass/groundunit/__init__.py:254, in GroundUnit.istransported(self)
#     253 def istransported(self):
# --> 254     return self._transported
#
# AttributeError: 'GroundUnit' object has no attribute '_transported'

# %%
# !zip -r counters.zip counters
# !rm -rf counters
