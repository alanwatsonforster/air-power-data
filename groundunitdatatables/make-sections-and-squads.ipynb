# %%
import sys
sys.path.append("../../glass/src")

# %%
import glass.data
import glob
import json

latexdir = "./"
datadir = "groundunitdata/"
samdatadir = "../samdata/"

# %%
for unitfilename in glob.glob("*platoon.json", root_dir="../groundunitdata/") + glob.glob(
    "*battery.json", root_dir="../groundunitdata/"
):

    basefilename = unitfilename[:-12]

    print("reading \"%s\"." % unitfilename)
    data = glass.data.loaddatafile("groundunitdata", unitfilename[:-5])

    # Don't make sections or squads for SAM or radar units.
    if "CCU" in data["name"] or "sam" in data or "radar" in data["symbols"]:
        continue

    print("  making \"%ssection.json\"." % basefilename)

    for member in ["name", "description", "symbols"]:
        data[member] = data[member].replace("platoon", "section")
        data[member] = data[member].replace("battery", "section")

    if "VPs" in data:
        data["VPs"] = data["VPs"][1:]

    if "aaa" in data:
        if data["aaa"]["class"] == "B":
            del data["aaa"]
        else:
            data["aaa"]["hitroll"] = list(
                max(0, hitroll - 1) for hitroll in data["aaa"]["hitroll"]
            )

    sectionpath = "../groundunitdata/" + basefilename + "section.json"
    with open(sectionpath, "w") as f:
        json.dump(data, f, indent=4)

    data = glass.data.loaddatafile("groundunitdata", unitfilename[:-5])

    # Don't make squads for air defense units.

    if "air-defense" in data["symbols"]:
        continue

    print("  making \"%ssquad.json\"." % basefilename)

    for member in ["name", "description", "symbols"]:
        data[member] = data[member].replace("platoon", "squad")
        data[member] = data[member].replace("battery", "squad")

    if "VPs" in data:
        data["VPs"] = data["VPs"][2:]

    if "aaa" in data:
        if data["aaa"]["class"] == "B":
            del data["aaa"]
        else:
            data["aaa"]["hitroll"] = list(
                max(0, hitroll - 2) for hitroll in data["aaa"]["hitroll"]
            )

    squadpath = "../groundunitdata/" + basefilename + "squad.json"
    with open(squadpath, "w") as f:
        json.dump(data, f, indent=4)
# Out:
# reading "infantry platoon.json".
#   making "infantry section.json".
#   making "infantry squad.json".
# reading "infantry weapons platoon.json".
#   making "infantry weapons section.json".
#   making "infantry weapons squad.json".
# reading "towed FCR-D platoon.json".
# reading "DShK-38 platoon.json".
#   making "DShK-38 section.json".
# reading "towed FCR-C platoon.json".
# reading "mobile EWR-B platoon.json".
# reading "open armored truck platoon.json".
#   making "open armored truck section.json".
#   making "open armored truck squad.json".
# reading "tracked carrier platoon.json".
#   making "tracked carrier section.json".
#   making "tracked carrier squad.json".
# reading "light IFV platoon.json".
#   making "light IFV section.json".
#   making "light IFV squad.json".
# reading "mobile CCU platoon.json".
# reading "Vz.53 platoon.json".
#   making "Vz.53 section.json".
# reading "towed FCR-B platoon.json".
# reading "medium tank platoon.json".
#   making "medium tank section.json".
#   making "medium tank squad.json".
# reading "light armored anti-tank missile platoon.json".
#   making "light armored anti-tank missile section.json".
#   making "light armored anti-tank missile squad.json".
# reading "M55 platoon.json".
#   making "M55 section.json".
# reading "TCM-20 platoon.json".
#   making "TCM-20 section.json".
# reading "light tank platoon.json".
#   making "light tank section.json".
#   making "light tank squad.json".
# reading "mobile HQ platoon.json".
#   making "mobile HQ section.json".
#   making "mobile HQ squad.json".
# reading "light APC platoon.json".
#   making "light APC section.json".
#   making "light APC squad.json".
# reading "infantry engineers platoon.json".
#   making "infantry engineers section.json".
#   making "infantry engineers squad.json".
# reading "light armored HQ platoon.json".
#   making "light armored HQ section.json".
#   making "light armored HQ squad.json".
# reading "infantry HQ platoon.json".
#   making "infantry HQ section.json".
#   making "infantry HQ squad.json".
# reading "M2 platoon.json".
#   making "M2 section.json".
# reading "open APC platoon.json".
#   making "open APC section.json".
#   making "open APC squad.json".
# reading "mobile anti-tank missile platoon.json".
#   making "mobile anti-tank missile section.json".
#   making "mobile anti-tank missile squad.json".
# reading "heavy APC platoon.json".
#   making "heavy APC section.json".
#   making "heavy APC squad.json".
# reading "towed mortar platoon.json".
#   making "towed mortar section.json".
#   making "towed mortar squad.json".
# reading "open armored reconnaissance platoon.json".
#   making "open armored reconnaissance section.json".
#   making "open armored reconnaissance squad.json".
# reading "medium APC platoon.json".
#   making "medium APC section.json".
#   making "medium APC squad.json".
# reading "light armored truck platoon.json".
#   making "light armored truck section.json".
#   making "light armored truck squad.json".
# reading "light truck platoon.json".
#   making "light truck section.json".
#   making "light truck squad.json".
# reading "heavy tank platoon.json".
#   making "heavy tank section.json".
#   making "heavy tank squad.json".
# reading "open tank platoon.json".
#   making "open tank section.json".
#   making "open tank squad.json".
# reading "M167 platoon.json".
#   making "M167 section.json".
# reading "medium armored anti-tank missile platoon.json".
#   making "medium armored anti-tank missile section.json".
#   making "medium armored anti-tank missile squad.json".
# reading "light armored mortar platoon.json".
#   making "light armored mortar section.json".
#   making "light armored mortar squad.json".
# reading "medium IFV platoon.json".
#   making "medium IFV section.json".
#   making "medium IFV squad.json".
# reading "light armored reconnaissance platoon.json".
#   making "light armored reconnaissance section.json".
#   making "light armored reconnaissance squad.json".
# reading "infantry mortar platoon.json".
#   making "infantry mortar section.json".
#   making "infantry mortar squad.json".
# reading "I-HAWK platoon.json".
# reading "mobile EWR-A platoon.json".
# reading "truck platoon.json".
#   making "truck section.json".
#   making "truck squad.json".
# reading "towed FCR-A platoon.json".
# reading "tracked missile artillery battery.json".
#   making "tracked missile artillery section.json".
#   making "tracked missile artillery squad.json".
# reading "light armored rocket artillery battery.json".
#   making "light armored rocket artillery section.json".
#   making "light armored rocket artillery squad.json".
# reading "mobile artillery battery.json".
#   making "mobile artillery section.json".
#   making "mobile artillery squad.json".
# reading "SA-2C battery.json".
# reading "mobile SA-3B battery.json".
# reading "Bofors L70 BOFI-R battery.json".
#   making "Bofors L70 BOFI-R section.json".
# reading "SA-10B battery.json".
# reading "SA-2E battery.json".
# reading "towed artillery battery.json".
#   making "towed artillery section.json".
#   making "towed artillery squad.json".
# reading "SA-2B battery.json".
# reading "SA-6B battery.json".
# reading "twin Rh-202 battery.json".
#   making "twin Rh-202 section.json".
# reading "SA-12A battery.json".
# reading "single Rh-202 battery.json".
#   making "single Rh-202 section.json".
# reading "mobile rocket artillery battery.json".
#   making "mobile rocket artillery section.json".
#   making "mobile rocket artillery squad.json".
# reading "90 mm M2 battery.json".
#   making "90 mm M2 section.json".
# reading "SA-4A battery.json".
# reading "tracked artillery battery.json".
#   making "tracked artillery section.json".
#   making "tracked artillery squad.json".
# reading "ZPU-1 battery.json".
#   making "ZPU-1 section.json".
# reading "Oerlikon GDF battery.json".
#   making "Oerlikon GDF section.json".
# reading "SA-5 battery.json".
# reading "MIM-104A battery.json".
# reading "Bofors L70 BOFI battery.json".
#   making "Bofors L70 BOFI section.json".
# reading "Bofors L60 battery.json".
#   making "Bofors L60 section.json".
# reading "Bofors L70 battery.json".
#   making "Bofors L70 section.json".
# reading "ZPU-2 battery.json".
#   making "ZPU-2 section.json".
# reading "S-60 battery.json".
#   making "S-60 section.json".
# reading "QF 3.7 inch battery.json".
#   making "QF 3.7 inch section.json".
# reading "120 mm M1 battery.json".
#   making "120 mm M1 section.json".
# reading "towed anti-tank gun battery.json".
#   making "towed anti-tank gun section.json".
#   making "towed anti-tank gun squad.json".
# reading "ZU-23 battery.json".
#   making "ZU-23 section.json".
# reading "KS-30 battery.json".
#   making "KS-30 section.json".
# reading "M51 battery.json".
#   making "M51 section.json".
# reading "KS-12 battery.json".
#   making "KS-12 section.json".
# reading "ZPU-4 battery.json".
#   making "ZPU-4 section.json".
# reading "SA-3B battery.json".
# reading "light armored artillery battery.json".
#   making "light armored artillery section.json".
#   making "light armored artillery squad.json".
# reading "SA-6A battery.json".
# reading "SA-2F battery.json".
# reading "SA-10A battery.json".
# reading "open armored artillery battery.json".
#   making "open armored artillery section.json".
#   making "open armored artillery squad.json".
# reading "mobile missile artillery battery.json".
#   making "mobile missile artillery section.json".
#   making "mobile missile artillery squad.json".
# reading "SA-4B battery.json".
# reading "KS-19 battery.json".
#   making "KS-19 section.json".
# reading "SA-12B battery.json".
