# %%
import glass.jsonc
import glob
import json

latexdir = "./"
datadir = "../groundunitdata/"
samdatadir = "../samdata/"

# %%
for unitpath in glob.glob(datadir + "*platoon.json") + glob.glob(datadir + "*battery.json"):

    basepath = unitpath[:-12]

    data = glass.jsonc.load(open(unitpath))

    # Don't make sections or squads for SAM or radar units.

    if "sam" in data or "radar" in data["symbols"]:
        continue

    sectionpath = basepath + "section.json"
    print(sectionpath)

    for member in ["name", "description", "symbols"]:
        data[member] = data[member].replace("platoon", "section")
        data[member] = data[member].replace("battery", "section")

    if "VPs" in data:
        data["VPs"] = data["VPs"][1:]

    if "aaa" in data:
        if data["aaa"]["class"] == "B":
            del data["aaa"]
        else:
            data["aaa"]["hitroll"] = list(max(0, hitroll - 1) for hitroll in data["aaa"]["hitroll"])
    
    with open(sectionpath, "w") as f:
        json.dump(data, f, indent=4)

    data = glass.jsonc.load(open(unitpath))

    # Don't make squads for air defense units.

    if "air-defense" in data["symbols"]:
        continue

    squadpath = basepath + "squad.json"
    print(squadpath)

    for member in ["name", "description", "symbols"]:
        data[member] = data[member].replace("platoon", "squad")
        data[member] = data[member].replace("battery", "squad")

    if "VPs" in data:
        data["VPs"] = data["VPs"][2:]

    if "aaa" in data:
        if data["aaa"]["class"] == "B":
            del data["aaa"]
        else:
            data["aaa"]["hitroll"] = list(max(0, hitroll - 2) for hitroll in data["aaa"]["hitroll"])
    
    with open(squadpath, "w") as f:
        json.dump(data, f, indent=4)
# Out:
# ../groundunitdata/infantry section.json
# ../groundunitdata/infantry squad.json
# ../groundunitdata/infantry weapons section.json
# ../groundunitdata/infantry weapons squad.json
# ../groundunitdata/light anti-tank section.json
# ../groundunitdata/light anti-tank squad.json
# ../groundunitdata/DShK-38 section.json
# ../groundunitdata/armored HQ section.json
# ../groundunitdata/armored HQ squad.json
# ../groundunitdata/tracked carrier section.json
# ../groundunitdata/tracked carrier squad.json
# ../groundunitdata/armored mortar section.json
# ../groundunitdata/armored mortar squad.json
# ../groundunitdata/light IFV section.json
# ../groundunitdata/light IFV squad.json
# ../groundunitdata/mobile CCU section.json
# ../groundunitdata/medium tank section.json
# ../groundunitdata/medium tank squad.json
# ../groundunitdata/M55 section.json
# ../groundunitdata/TCM-20 section.json
# ../groundunitdata/light tank section.json
# ../groundunitdata/light tank squad.json
# ../groundunitdata/mobile HQ section.json
# ../groundunitdata/mobile HQ squad.json
# ../groundunitdata/light APC section.json
# ../groundunitdata/light APC squad.json
# ../groundunitdata/infantry HQ section.json
# ../groundunitdata/infantry HQ squad.json
# ../groundunitdata/M2 section.json
# ../groundunitdata/open APC section.json
# ../groundunitdata/open APC squad.json
# ../groundunitdata/heavy APC section.json
# ../groundunitdata/heavy APC squad.json
# ../groundunitdata/towed mortar section.json
# ../groundunitdata/towed mortar squad.json
# ../groundunitdata/medium APC section.json
# ../groundunitdata/medium APC squad.json
# ../groundunitdata/light truck section.json
# ../groundunitdata/light truck squad.json
# ../groundunitdata/heavy tank section.json
# ../groundunitdata/heavy tank squad.json
# ../groundunitdata/medium anti-tank section.json
# ../groundunitdata/medium anti-tank squad.json
# ../groundunitdata/open tank section.json
# ../groundunitdata/open tank squad.json
# ../groundunitdata/M167 section.json
# ../groundunitdata/medium IFV section.json
# ../groundunitdata/medium IFV squad.json
# ../groundunitdata/infantry mortar section.json
# ../groundunitdata/infantry mortar squad.json
# ../groundunitdata/light reconnaissance section.json
# ../groundunitdata/light reconnaissance squad.json
# ../groundunitdata/truck section.json
# ../groundunitdata/truck squad.json
# ../groundunitdata/tracked missile artillery section.json
# ../groundunitdata/tracked missile artillery squad.json
# ../groundunitdata/mobile artillery section.json
# ../groundunitdata/mobile artillery squad.json
# ../groundunitdata/armored artillery section.json
# ../groundunitdata/armored artillery squad.json
# ../groundunitdata/armored rocket artillery section.json
# ../groundunitdata/armored rocket artillery squad.json
# ../groundunitdata/Bofors L70 BOFI-R section.json
# ../groundunitdata/towed artillery section.json
# ../groundunitdata/towed artillery squad.json
# ../groundunitdata/twin Rh-202 section.json
# ../groundunitdata/single Rh-202 section.json
# ../groundunitdata/mobile rocket artillery section.json
# ../groundunitdata/mobile rocket artillery squad.json
# ../groundunitdata/tracked artillery section.json
# ../groundunitdata/tracked artillery squad.json
# ../groundunitdata/ZPU-1 section.json
# ../groundunitdata/Oerlikon GDF section.json
# ../groundunitdata/Bofors L70 BOFI section.json
# ../groundunitdata/Bofors L60 section.json
# ../groundunitdata/Bofors L70 section.json
# ../groundunitdata/ZPU-2 section.json
# ../groundunitdata/S-60 section.json
# ../groundunitdata/ZU-23 section.json
# ../groundunitdata/KS-12 section.json
# ../groundunitdata/ZPU-4 section.json
# ../groundunitdata/mobile missile artillery section.json
# ../groundunitdata/mobile missile artillery squad.json
# ../groundunitdata/KS-19 section.json
# ../groundunitdata/61-K section.json
