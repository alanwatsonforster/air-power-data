# %%
import sys

sys.path.append("../../glass/src")

# %%
import glass
import glass.draw

import math
import os

# !mkdir -p counters

def drawcounter(
    type, color="white", sighted=False, identified=False, azimuth=None, protectionclass=None,
    name="",
):

    glass.startgamesetup(None, sheets=[["A"]], writelogfiles=False)

    E = glass.setupgroundunit(
        name,
        type=type,
        hexcode="origin",
        color=color,
        counter=True,
        sighted=sighted,
        identified=identified,
        azimuth=azimuth,
    )

    groundunitcountersize = 0.6 * math.sqrt(4 / 3)
    dotspercounter = 300
    dotsperhex = dotspercounter / groundunitcountersize

    glass.draw.startcanvas(
        -0.51 * groundunitcountersize * math.sqrt(4/3),
        -0.51 * groundunitcountersize,
        +0.51 * groundunitcountersize * math.sqrt(4/3),
        +0.51 * groundunitcountersize,
        dotsperhex=dotsperhex,
    )

    #E.takedamage("2D")

    E._draw()

    glass.draw.writecanvastofile("counters/%s.png" % (type))
    glass.draw.writecanvastofile("counters/%s.pdf" % (type))


drawcounter("infantry platoon", identified=True, name="1A2")
drawcounter("light ifv platoon", identified=True, name="M1A2")
# Out:
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit 1A2.
# set-up      :       :       : type is infantry platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit M1A2.
# set-up      :       :       : type is light ifv platoon.

# %%
os.system("rm -rf counters/")
os.system("mkdir -p counters/")

color = "white"

for name in [
    "infantry platoon",
    "infantry weapons platoon",
    "infantry mortar platoon",
    "infantry engineers platoon",
    "infantry FAC squad",
    "infantry SAM squad",
    "infantry heavy SAM squad",
    "infantry HQ platoon",
    "heavy tank platoon",
    "medium tank platoon",
    "light tank platoon",
    "open tank platoon",
    "medium armored anti-tank missile platoon",
    "light armored anti-tank missile platoon",
    "light armored reconnaissance platoon",
    "open armored reconnaissance platoon",
    "medium IFV platoon",
    "light IFV platoon",
    "heavy APC platoon",
    "medium APC platoon",
    "light APC platoon",
    "open APC platoon",
    "light armored mortar platoon",
    "light armored artillery battery",
    "open armored artillery battery",
    "light armored rocket artillery battery",
    "light armored HQ platoon",
    "light armored truck platoon",
    "open armored truck platoon",
    "truck platoon",
    "light truck platoon",
    "tracked carrier platoon",
    "mobile anti-tank missile platoon",
    "mobile artillery battery",
    "tracked artillery battery",
    "mobile rocket artillery battery",
    "tracked missile artillery battery",
    "mobile missile artillery battery",
    "mobile HQ platoon",
    "towed anti-tank gun battery",
    "towed mortar platoon",
    "towed artillery battery",
    "M2 platoon",
    "DShK platoon",
    "M16 section",
    "M17 section",
    "M55 platoon",
    "Vz.53 platoon",
    "BTR-152A VZ.53 section",
    "mobile M45 section",
    "ZPU-1 battery",
    "ZPU-2 battery",
    "ZPU-4 battery",
    "mobile ZPU-1 section",
    "mobile ZPU-2 section",
    "mobile ZPU-4 section",
    "BTR-40A section",
    "BTR-152A ZPU-2 section",
    "BTR-152A ZPU-4 section",
    "M167 platoon",
    "M163 section",
    "TCM-20 platoon",
    "M3 TCM-20 section",
    "Rh-202 battery",
    "Panhard M3 VDA section",
    "ZU-23 battery",
    "mobile ZU-23 section",
    "BTR-152A ZU-23 section",
    "Sinai 23 Ayn-al-Saqr section",
    "Sinai 23 Stinger section",
    "ZSU-23-4 section",
    "LAV-AD section",
    "M5359 section",
    "AMX-13 DCA section",
    "AMX-30SA section",
    "Tunguska section",
    "Tunguska-M section",
    # "Pantsir section",
    "Oerlikon GDF battery",
    "Gepard section",
    "61-K battery",
    "M15 section",
    "Bofors L60 battery",
    "M19 section",
    "M34 section",
    "M42 section",
    "Bofors L70 battery",
    "Bofors L70 BOFI battery",
    "Bofors L70 BOFI-R battery",
    "S-60 battery",
    "ZSU-57-2 section",
    "M51 battery",
    "towed FCR-A platoon",
    "towed FCR-B platoon",
    "towed FCR-C platoon",
    "towed FCR-D platoon",
    "mobile FCR-A platoon",
    "mobile FCR-B platoon",
    "mobile FCR-C platoon",
    "mobile FCR-D platoon",
    # "towed EWR-A",
    # "mobile EWR-A",
    # "mobile CCU section",
    # "armored CCU section",
    "SA-7A squad",
    "SA-7B squad",
    "SA-14 squad",
    "SA-16 squad",
    "SA-18 squad",
    "FIM-43C squad",
    "FIM-92A squad",
    "FIM-92B squad",
    "FIM-92C squad",
    "FIM-92D squad",
    "Blowpipe squad",
    "Javelin squad",
    "Starburst squad",
    "Starstreak squad",
    "Starstreak LML squad",
    "Mistral squad",
    "RBS 70 squad",
    "Ayn-al-Saqr squad",
    "SA-2B battery",
    "SA-2C battery",
    "SA-2E battery",
    "SA-2F battery",
    "SA-3B battery",
    "mobile SA-3B battery",
    "SA-4A battery",
    "SA-4B battery",
    "SA-6A battery",
    "SA-6B battery",
    "SA-8A squad",
    "SA-8B squad",
    "SA-9A squad",
    "SA-9B squad",
    "SA-11 squad",
    "SA-13 squad",
    # "SA-5 battery",
    # "SA-10A battery",
    # "SA-10B battery",
    # "SA-12A battery",
    # "SA-12B battery",
    # "SA-13 squad",
    # "SA-15 squad",
    # "SA-17 squad",
    # "Tunguska section",
    # "Pantsir section",
    "M48 squad",
    "I-HAWK platoon",
    "MIM-104A battery",
]:
    drawcounter(name, color=color, identified=True)
for name in [
    "Flab Kan 38 battery",
    "KS-12 battery",
    "90 mm M2 battery",
    "QF 3.7-inch battery",
    "KS-19 battery",
    "120 mm M1 battery",
    "KS-30 battery",
    "QF 5.25-inch battery",
]:
    drawcounter(name, color=color, identified=True, azimuth=0)
for name in [
    "unidentified air-defense 12",
    "unidentified air-defense 18",
    "unidentified armor",
    "unidentified artillery",
    "unidentified infantry",
    "unidentified radar",
    "unidentified truck",
]:
    drawcounter(name, color=color, sighted=True)
for name in [
    "unsighted",
]:
    drawcounter(name, color=color)
# Out:
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is infantry platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is infantry weapons platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is infantry mortar platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is infantry engineers platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is infantry FAC squad.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is infantry SAM squad.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is infantry heavy SAM squad.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is infantry HQ platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is heavy tank platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is medium tank platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is light tank platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is open tank platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is medium armored anti-tank missile platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is light armored anti-tank missile platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is light armored reconnaissance platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is open armored reconnaissance platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is medium IFV platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is light IFV platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is heavy APC platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is medium APC platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is light APC platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is open APC platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is light armored mortar platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is light armored artillery battery.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is open armored artillery battery.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is light armored rocket artillery battery.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is light armored HQ platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is light armored truck platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is open armored truck platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is truck platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is light truck platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is tracked carrier platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is mobile anti-tank missile platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is mobile artillery battery.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is tracked artillery battery.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is mobile rocket artillery battery.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is tracked missile artillery battery.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is mobile missile artillery battery.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is mobile HQ platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is towed anti-tank gun battery.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is towed mortar platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is towed artillery battery.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is M2 platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is DShK platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is M16 section.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is M17 section.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is M55 platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is Vz.53 platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is BTR-152A VZ.53 section.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is mobile M45 section.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is ZPU-1 battery.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is ZPU-2 battery.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is ZPU-4 battery.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is mobile ZPU-1 section.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is mobile ZPU-2 section.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is mobile ZPU-4 section.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is BTR-40A section.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is BTR-152A ZPU-2 section.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is BTR-152A ZPU-4 section.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is M167 platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is M163 section.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is TCM-20 platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is M3 TCM-20 section.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is Rh-202 battery.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is Panhard M3 VDA section.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is ZU-23 battery.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is mobile ZU-23 section.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is BTR-152A ZU-23 section.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is Sinai 23 Ayn-al-Saqr section.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is Sinai 23 Stinger section.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is ZSU-23-4 section.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is LAV-AD section.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is M5359 section.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is AMX-13 DCA section.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is AMX-30SA section.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is Tunguska section.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is Tunguska-M section.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is Oerlikon GDF battery.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is Gepard section.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is 61-K battery.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is M15 section.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is Bofors L60 battery.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is M19 section.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is M34 section.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is M42 section.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is Bofors L70 battery.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is Bofors L70 BOFI battery.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is Bofors L70 BOFI-R battery.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is S-60 battery.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is ZSU-57-2 section.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is M51 battery.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is towed FCR-A platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is towed FCR-B platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is towed FCR-C platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is towed FCR-D platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is mobile FCR-A platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is mobile FCR-B platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is mobile FCR-C platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is mobile FCR-D platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is SA-7A squad.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is SA-7B squad.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is SA-14 squad.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is SA-16 squad.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is SA-18 squad.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is FIM-43C squad.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is FIM-92A squad.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is FIM-92B squad.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is FIM-92C squad.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is FIM-92D squad.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is Blowpipe squad.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is Javelin squad.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is Starburst squad.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is Starstreak squad.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is Starstreak LML squad.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is Mistral squad.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is RBS 70 squad.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is Ayn-al-Saqr squad.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is SA-2B battery.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is SA-2C battery.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is SA-2E battery.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is SA-2F battery.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is SA-3B battery.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is mobile SA-3B battery.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is SA-4A battery.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is SA-4B battery.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is SA-6A battery.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is SA-6B battery.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is SA-8A squad.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is SA-8B squad.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is SA-9A squad.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is SA-9B squad.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is SA-11 squad.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is SA-13 squad.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is M48 squad.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is I-HAWK platoon.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is MIM-104A battery.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is Flab Kan 38 battery.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is KS-12 battery.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is 90 mm M2 battery.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is QF 3.7-inch battery.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is KS-19 battery.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is 120 mm M1 battery.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is KS-30 battery.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is QF 5.25-inch battery.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is unidentified air-defense 12.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is unidentified air-defense 18.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is unidentified armor.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is unidentified artillery.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is unidentified infantry.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is unidentified radar.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is unidentified truck.
#
# set-up      : start of game set-up.
# set-up      : no scenario specified.
# set-up      : sheets are [['A']].
# set-up      : north is up.
#
# set-up      :       :       : creating ground unit .
# set-up      :       :       : type is unsighted.

# %%
# !zip -r counters.zip counters
# Out:
# updating: counters/ (stored 0%)
# updating: counters/ZPU-2 battery.png (deflated 11%)
# updating: counters/light truck platoon.png (deflated 14%)
# updating: counters/light IFV platoon.png (deflated 13%)
# updating: counters/SA-9A squad.png (deflated 7%)
# updating: counters/tracked missile artillery battery.png (deflated 13%)
# updating: counters/KS-12 battery.png (deflated 11%)
# updating: counters/AMX-30SA section.png (deflated 8%)
# updating: counters/medium IFV platoon.png (deflated 11%)
# updating: counters/ZSU-23-4 section.png (deflated 8%)
# updating: counters/Sinai 23 Stinger section.png (deflated 7%)
# updating: counters/TCM-20 platoon.png (deflated 10%)
# updating: counters/light armored rocket artillery battery.png (deflated 12%)
# updating: counters/towed artillery battery.png (deflated 14%)
# updating: counters/M3 TCM-20 section.png (deflated 7%)
# updating: counters/mobile missile artillery battery.png (deflated 14%)
# updating: counters/SA-4A battery.png (deflated 8%)
# updating: counters/unidentified truck.png (deflated 24%)
# updating: counters/tracked carrier platoon.png (deflated 15%)
# updating: counters/mobile ZU-23 section.png (deflated 10%)
# updating: counters/S-60 battery.png (deflated 12%)
# updating: counters/I-HAWK platoon.png (deflated 8%)
# updating: counters/SA-7B squad.png (deflated 7%)
# updating: counters/ZSU-57-2 section.png (deflated 8%)
# updating: counters/infantry HQ platoon.png (deflated 12%)
# updating: counters/unidentified infantry.png (deflated 15%)
# updating: counters/ZPU-4 battery.png (deflated 10%)
# updating: counters/open armored artillery battery.png (deflated 13%)
# updating: counters/SA-4B battery.png (deflated 8%)
# updating: counters/light armored artillery battery.png (deflated 12%)
# updating: counters/SA-3B battery.png (deflated 9%)
# updating: counters/heavy APC platoon.png (deflated 12%)
# updating: counters/M167 platoon.png (deflated 9%)
# updating: counters/mobile rocket artillery battery.png (deflated 12%)
# updating: counters/SA-8B squad.png (deflated 8%)
# updating: counters/unidentified air-defense 12.png (deflated 16%)
# updating: counters/MIM-104A battery.png (deflated 8%)
# updating: counters/light APC platoon.png (deflated 12%)
# updating: counters/infantry SAM squad.png (deflated 7%)
# updating: counters/unidentified artillery.png (deflated 19%)
# updating: counters/heavy tank platoon.png (deflated 12%)
# updating: counters/tracked artillery battery.png (deflated 13%)
# updating: counters/towed anti-tank gun battery.png (deflated 12%)
# updating: counters/mobile artillery battery.png (deflated 13%)
# updating: counters/SA-11 squad.png (deflated 8%)
# updating: counters/medium tank platoon.png (deflated 12%)
# updating: counters/medium APC platoon.png (deflated 11%)
# updating: counters/Oerlikon GDF battery.png (deflated 11%)
# updating: counters/light armored reconnaissance platoon.png (deflated 9%)
# updating: counters/M55 platoon.png (deflated 10%)
# updating: counters/SA-2B battery.png (deflated 9%)
# updating: counters/LAV-AD section.png (deflated 7%)
# updating: counters/ZPU-1 battery.png (deflated 11%)
# updating: counters/Gepard section.png (deflated 8%)
# updating: counters/unidentified armor.png (deflated 14%)
# updating: counters/SA-2E battery.png (deflated 10%)
# updating: counters/light tank platoon.png (deflated 11%)
# updating: counters/infantry weapons platoon.png (deflated 11%)
# updating: counters/open tank platoon.png (deflated 11%)
# updating: counters/mobile ZPU-1 section.png (deflated 11%)
# updating: counters/light armored mortar platoon.png (deflated 12%)
# updating: counters/M5359 section.png (deflated 8%)
# updating: counters/infantry platoon.png (deflated 12%)
# updating: counters/infantry mortar platoon.png (deflated 11%)
# updating: counters/mobile ZPU-4 section.png (deflated 10%)
# updating: counters/M2 platoon.png (deflated 8%)
# updating: counters/61-K battery.png (deflated 11%)
# updating: counters/towed mortar platoon.png (deflated 13%)
# updating: counters/unidentified radar.png (deflated 17%)
# updating: counters/SA-8A squad.png (deflated 8%)
# updating: counters/unidentified air-defense 18.png (deflated 15%)
# updating: counters/truck platoon.png (deflated 14%)
# updating: counters/SA-6B battery.png (deflated 8%)
# updating: counters/unsighted.png (deflated 67%)
# updating: counters/Tunguska section.png (deflated 7%)
# updating: counters/M48 squad.png (deflated 8%)
# updating: counters/SA-2C battery.png (deflated 9%)
# updating: counters/SA-9B squad.png (deflated 8%)
# updating: counters/KS-19 battery.png (deflated 11%)
# updating: counters/open APC platoon.png (deflated 11%)
# updating: counters/light armored HQ platoon.png (deflated 12%)
# updating: counters/SA-6A battery.png (deflated 8%)
# updating: counters/Bofors L70 battery.png (deflated 11%)
# updating: counters/infantry heavy SAM squad.png (deflated 7%)
# updating: counters/Bofors L70 BOFI-R battery.png (deflated 11%)
# updating: counters/ZU-23 battery.png (deflated 10%)
# updating: counters/infantry FAC squad.png (deflated 12%)
# updating: counters/Tunguska-M section.png (deflated 7%)
# updating: counters/Bofors L70 BOFI battery.png (deflated 11%)
# updating: counters/mobile HQ platoon.png (deflated 15%)
# updating: counters/mobile SA-3B battery.png (deflated 9%)
# updating: counters/light armored anti-tank missile platoon.png (deflated 11%)
# updating: counters/Bofors L60 battery.png (deflated 11%)
# updating: counters/Sinai 23 Ayn-al-Saqr section.png (deflated 7%)
# updating: counters/mobile ZPU-2 section.png (deflated 10%)
# updating: counters/medium armored anti-tank missile platoon.png (deflated 10%)
# updating: counters/M16 section.png (deflated 8%)
# updating: counters/SA-7A squad.png (deflated 7%)
# updating: counters/open armored reconnaissance platoon.png (deflated 9%)
# updating: counters/SA-2F battery.png (deflated 9%)
# updating: counters/SA-13 squad.png (deflated 8%)
# updating: counters/M163 section.png (deflated 8%)
# updating: counters/towed FCR-B platoon.png (deflated 9%)
# updating: counters/towed FCR-D platoon.png (deflated 9%)
# updating: counters/towed FCR-A platoon.png (deflated 8%)
# updating: counters/towed FCR-C platoon.png (deflated 9%)
# updating: counters/mobile anti-tank missile platoon.png (deflated 13%)
# updating: counters/SA-14 squad.png (deflated 8%)
# updating: counters/Starstreak LML squad.png (deflated 7%)
# updating: counters/Blowpipe squad.png (deflated 6%)
# updating: counters/SA-16 squad.png (deflated 7%)
# updating: counters/FIM-92A squad.png (deflated 7%)
# updating: counters/FIM-92D squad.png (deflated 7%)
# updating: counters/Mistral squad.png (deflated 7%)
# updating: counters/RBS 70 squad.png (deflated 7%)
# updating: counters/Ayn-al-Saqr squad.png (deflated 7%)
# updating: counters/Starburst squad.png (deflated 7%)
# updating: counters/FIM-92B squad.png (deflated 7%)
# updating: counters/Starstreak squad.png (deflated 8%)
# updating: counters/SA-18 squad.png (deflated 7%)
# updating: counters/FIM-43C squad.png (deflated 7%)
# updating: counters/Javelin squad.png (deflated 7%)
# updating: counters/FIM-92C squad.png (deflated 8%)
# updating: counters/infantry engineers platoon.png (deflated 11%)
# updating: counters/90 mm M2 battery.png (deflated 11%)
# updating: counters/KS-30 battery.png (deflated 11%)
# updating: counters/120 mm M1 battery.png (deflated 11%)
# updating: counters/M51 battery.png (deflated 11%)
# updating: counters/M42 section.png (deflated 7%)
# updating: counters/M19 section.png (deflated 7%)
# updating: counters/Panhard M3 VDA section.png (deflated 8%)
# updating: counters/M17 section.png (deflated 8%)
# updating: counters/mobile M45 section.png (deflated 10%)
# updating: counters/BTR-40A section.png (deflated 8%)
# updating: counters/BTR-152A ZPU-4 section.png (deflated 8%)
# updating: counters/BTR-152A ZPU-2 section.png (deflated 8%)
# updating: counters/BTR-152A ZU-23 section.png (deflated 8%)
# updating: counters/Vz.53 platoon.png (deflated 10%)
# updating: counters/BTR-152A VZ.53 section.png (deflated 8%)
# updating: counters/open armored truck platoon.png (deflated 10%)
# updating: counters/light armored truck platoon.png (deflated 11%)
# updating: counters/M15 section.png (deflated 8%)
# updating: counters/M34 section.png (deflated 11%)
# updating: counters/Flab Kan 38 battery.png (deflated 11%)
# updating: counters/QF 5.25-inch battery.png (deflated 11%)
# updating: counters/mobile FCR-C platoon.png (deflated 9%)
# updating: counters/mobile FCR-A platoon.png (deflated 8%)
# updating: counters/mobile FCR-D platoon.png (deflated 9%)
# updating: counters/QF 3.7-inch battery.png (deflated 11%)
# updating: counters/mobile FCR-B platoon.png (deflated 8%)
# updating: counters/DShK platoon.png (deflated 8%)
# updating: counters/Rh-202 battery.png (deflated 10%)
# updating: counters/AMX-13 DCA section.png (deflated 8%)
# updating: counters/light armored rocket artillery battery.pdf (deflated 38%)
# updating: counters/towed FCR-B platoon.pdf (deflated 35%)
# updating: counters/SA-16 squad.pdf (deflated 39%)
# updating: counters/KS-12 battery.pdf (deflated 40%)
# updating: counters/Blowpipe squad.pdf (deflated 37%)
# updating: counters/AMX-30SA section.pdf (deflated 35%)
# updating: counters/medium IFV platoon.pdf (deflated 36%)
# updating: counters/ZSU-23-4 section.pdf (deflated 35%)
# updating: counters/Sinai 23 Stinger section.pdf (deflated 35%)
# updating: counters/TCM-20 platoon.pdf (deflated 37%)
# updating: counters/SA-9A squad.pdf (deflated 35%)
# updating: counters/tracked missile artillery battery.pdf (deflated 45%)
# updating: counters/BTR-152A ZU-23 section.pdf (deflated 34%)
# updating: counters/Starstreak LML squad.pdf (deflated 42%)
# updating: counters/QF 5.25-inch battery.pdf (deflated 39%)
# updating: counters/ZPU-2 battery.pdf (deflated 39%)
# updating: counters/light truck platoon.pdf (deflated 49%)
# updating: counters/light IFV platoon.pdf (deflated 37%)
# updating: counters/Vz.53 platoon.pdf (deflated 39%)
# updating: counters/mobile ZU-23 section.pdf (deflated 38%)
# updating: counters/S-60 battery.pdf (deflated 39%)
# updating: counters/open armored truck platoon.pdf (deflated 34%)
# updating: counters/Rh-202 battery.pdf (deflated 39%)
# updating: counters/SA-7B squad.pdf (deflated 38%)
# updating: counters/I-HAWK platoon.pdf (deflated 40%)
# updating: counters/unidentified truck.pdf (deflated 48%)
# updating: counters/KS-30 battery.pdf (deflated 38%)
# updating: counters/tracked carrier platoon.pdf (deflated 51%)
# updating: counters/mobile missile artillery battery.pdf (deflated 43%)
# updating: counters/SA-4A battery.pdf (deflated 35%)
# updating: counters/towed artillery battery.pdf (deflated 41%)
# updating: counters/M3 TCM-20 section.pdf (deflated 34%)
# updating: counters/heavy APC platoon.pdf (deflated 35%)
# updating: counters/M167 platoon.pdf (deflated 35%)
# updating: counters/mobile rocket artillery battery.pdf (deflated 44%)
# updating: counters/SA-4B battery.pdf (deflated 35%)
# updating: counters/light armored artillery battery.pdf (deflated 37%)
# updating: counters/SA-3B battery.pdf (deflated 38%)
# updating: counters/towed FCR-D platoon.pdf (deflated 36%)
# updating: counters/M17 section.pdf (deflated 35%)
# updating: counters/infantry engineers platoon.pdf (deflated 49%)
# updating: counters/ZPU-4 battery.pdf (deflated 39%)
# updating: counters/open armored artillery battery.pdf (deflated 36%)
# updating: counters/Panhard M3 VDA section.pdf (deflated 36%)
# updating: counters/mobile FCR-C platoon.pdf (deflated 38%)
# updating: counters/ZSU-57-2 section.pdf (deflated 35%)
# updating: counters/infantry HQ platoon.pdf (deflated 43%)
# updating: counters/120 mm M1 battery.pdf (deflated 38%)
# updating: counters/unidentified infantry.pdf (deflated 48%)
# updating: counters/LAV-AD section.pdf (deflated 35%)
# updating: counters/SA-2B battery.pdf (deflated 38%)
# updating: counters/ZPU-1 battery.pdf (deflated 39%)
# updating: counters/Gepard section.pdf (deflated 35%)
# updating: counters/SA-11 squad.pdf (deflated 35%)
# updating: counters/medium APC platoon.pdf (deflated 36%)
# updating: counters/90 mm M2 battery.pdf (deflated 38%)
# updating: counters/medium tank platoon.pdf (deflated 35%)
# updating: counters/Oerlikon GDF battery.pdf (deflated 39%)
# updating: counters/M55 platoon.pdf (deflated 39%)
# updating: counters/light armored reconnaissance platoon.pdf (deflated 36%)
# updating: counters/unidentified artillery.pdf (deflated 45%)
# updating: counters/infantry SAM squad.pdf (deflated 38%)
# updating: counters/heavy tank platoon.pdf (deflated 35%)
# updating: counters/BTR-40A section.pdf (deflated 34%)
# updating: counters/tracked artillery battery.pdf (deflated 44%)
# updating: counters/towed anti-tank gun battery.pdf (deflated 44%)
# updating: counters/mobile artillery battery.pdf (deflated 43%)
# updating: counters/MIM-104A battery.pdf (deflated 41%)
# updating: counters/towed FCR-A platoon.pdf (deflated 36%)
# updating: counters/SA-8B squad.pdf (deflated 33%)
# updating: counters/unidentified air-defense 12.pdf (deflated 47%)
# updating: counters/light armored truck platoon.pdf (deflated 36%)
# updating: counters/light APC platoon.pdf (deflated 37%)
# updating: counters/FIM-92A squad.pdf (deflated 39%)
# updating: counters/light armored mortar platoon.pdf (deflated 36%)
# updating: counters/M5359 section.pdf (deflated 35%)
# updating: counters/Ayn-al-Saqr squad.pdf (deflated 36%)
# updating: counters/infantry platoon.pdf (deflated 43%)
# updating: counters/infantry mortar platoon.pdf (deflated 39%)
# updating: counters/infantry weapons platoon.pdf (deflated 47%)
# updating: counters/M15 section.pdf (deflated 36%)
# updating: counters/open tank platoon.pdf (deflated 35%)
# updating: counters/BTR-152A ZPU-4 section.pdf (deflated 34%)
# updating: counters/mobile ZPU-1 section.pdf (deflated 39%)
# updating: counters/SA-14 squad.pdf (deflated 38%)
# updating: counters/BTR-152A VZ.53 section.pdf (deflated 35%)
# updating: counters/SA-2E battery.pdf (deflated 39%)
# updating: counters/mobile FCR-A platoon.pdf (deflated 38%)
# updating: counters/Mistral squad.pdf (deflated 45%)
# updating: counters/light tank platoon.pdf (deflated 36%)
# updating: counters/mobile M45 section.pdf (deflated 41%)
# updating: counters/RBS 70 squad.pdf (deflated 45%)
# updating: counters/FIM-92D squad.pdf (deflated 38%)
# updating: counters/unidentified armor.pdf (deflated 28%)
# updating: counters/M42 section.pdf (deflated 35%)
# updating: counters/Flab Kan 38 battery.pdf (deflated 40%)
# updating: counters/Tunguska section.pdf (deflated 34%)
# updating: counters/DShK platoon.pdf (deflated 40%)
# updating: counters/mobile FCR-D platoon.pdf (deflated 38%)
# updating: counters/M48 squad.pdf (deflated 35%)
# updating: counters/truck platoon.pdf (deflated 49%)
# updating: counters/Starstreak squad.pdf (deflated 35%)
# updating: counters/unidentified air-defense 18.pdf (deflated 45%)
# updating: counters/M19 section.pdf (deflated 35%)
# updating: counters/unsighted.pdf (deflated 43%)
# updating: counters/M51 battery.pdf (deflated 38%)
# updating: counters/SA-6B battery.pdf (deflated 34%)
# updating: counters/towed mortar platoon.pdf (deflated 37%)
# updating: counters/61-K battery.pdf (deflated 40%)
# updating: counters/M2 platoon.pdf (deflated 40%)
# updating: counters/AMX-13 DCA section.pdf (deflated 35%)
# updating: counters/FIM-92B squad.pdf (deflated 38%)
# updating: counters/unidentified radar.pdf (deflated 46%)
# updating: counters/SA-8A squad.pdf (deflated 33%)
# updating: counters/Starburst squad.pdf (deflated 34%)
# updating: counters/mobile ZPU-4 section.pdf (deflated 39%)
# updating: counters/towed FCR-C platoon.pdf (deflated 36%)
# updating: counters/Bofors L70 BOFI battery.pdf (deflated 39%)
# updating: counters/BTR-152A ZPU-2 section.pdf (deflated 34%)
# updating: counters/light armored anti-tank missile platoon.pdf (deflated 36%)
# updating: counters/mobile SA-3B battery.pdf (deflated 35%)
# updating: counters/mobile HQ platoon.pdf (deflated 40%)
# updating: counters/Bofors L70 BOFI-R battery.pdf (deflated 39%)
# updating: counters/infantry FAC squad.pdf (deflated 50%)
# updating: counters/ZU-23 battery.pdf (deflated 40%)
# updating: counters/FIM-43C squad.pdf (deflated 39%)
# updating: counters/Tunguska-M section.pdf (deflated 34%)
# updating: counters/light armored HQ platoon.pdf (deflated 37%)
# updating: counters/SA-6A battery.pdf (deflated 34%)
# updating: counters/M34 section.pdf (deflated 41%)
# updating: counters/infantry heavy SAM squad.pdf (deflated 46%)
# updating: counters/Bofors L70 battery.pdf (deflated 39%)
# updating: counters/SA-2C battery.pdf (deflated 38%)
# updating: counters/SA-18 squad.pdf (deflated 37%)
# updating: counters/SA-9B squad.pdf (deflated 34%)
# updating: counters/KS-19 battery.pdf (deflated 40%)
# updating: counters/open APC platoon.pdf (deflated 35%)
# updating: counters/SA-13 squad.pdf (deflated 35%)
# updating: counters/M163 section.pdf (deflated 35%)
# updating: counters/open armored reconnaissance platoon.pdf (deflated 35%)
# updating: counters/SA-7A squad.pdf (deflated 39%)
# updating: counters/mobile FCR-B platoon.pdf (deflated 37%)
# updating: counters/SA-2F battery.pdf (deflated 39%)
# updating: counters/mobile ZPU-2 section.pdf (deflated 39%)
# updating: counters/medium armored anti-tank missile platoon.pdf (deflated 35%)
# updating: counters/M16 section.pdf (deflated 35%)
# updating: counters/FIM-92C squad.pdf (deflated 38%)
# updating: counters/mobile anti-tank missile platoon.pdf (deflated 39%)
# updating: counters/Bofors L60 battery.pdf (deflated 39%)
# updating: counters/QF 3.7-inch battery.pdf (deflated 39%)
# updating: counters/Sinai 23 Ayn-al-Saqr section.pdf (deflated 34%)
# updating: counters/Javelin squad.pdf (deflated 38%)
